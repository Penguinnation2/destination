# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
Doc='''Pathaan is a 2023 Indian Hindi-language action thriller film directed by Siddharth Anand and produced by Aditya Chopra of Yash Raj Films. The fourth instalment in the YRF Spy Universe, it stars Shah Rukh Khan, Deepika Padukone, and John Abraham, alongside Dimple Kapadia and Ashutosh Rana. Written by Shridhar Raghavan and Abbas Tyrewala from a story by Anand, the film is about Pathaan, an exiled RAW agent, who must work with ISI agent Rubina to take down Jim, a former RAW agent-turned-traitor, who is planning to spread a deadly lab-generated virus across India.
Principal photography for Pathaan began in November 2020 in Mumbai. The film was shot over various locations in India, Afghanistan, Spain, UAE, Turkey, Russia, Italy and France. Two songs were composed by the duo Vishal–Shekhar, while Sanchit Balhara and Ankit Balhara provided the score. The music video of one song, "Besharam Rang", featured Padukone in a saffron bikini, which led to protests by right-wing Hindutva groups and an attempt to boycott the film; however, the Central Board of Film Certification cleared the film for exhibition after certain edits were made to the song sequence. The film was made on an estimated production budget of ₹225 crore (US$28 million) with a further ₹15 crore (US$1.9 million) spent on print and advertising. Against the norm, pre-release publicity was limited with no media interactions or public events.
Pathaan was released in India on 25 January 2023, coinciding with the Republic Day weekend, in IMAX, 4DX and standard formats along with dubbed versions in Tamil and Telugu. It received positive reviews from critics and broke several Indian box-office records, including the biggest opening day and opening weekend for a Hindi film. Further opening records were set in overseas markets. Grossing ₹924 crore (US$120 million) worldwide, Pathaan ranks as the highest-grossing Hindi film of 2023, the fourth-highest-grossing Hindi film and seventh-highest-grossing Indian film of all time, as well as the highest-grossing of Khan's career and Yash Raj Films' releases. 
In 2019, the Indian Government revokes Article 370, which grants special status for Jammu and Kashmir. The news impacts a cancer-ridden Pakistani army general, Qadir, who decides to exact vengeance against India. He signs a contract with Jim, who leads "Outfit X", a private terrorist organization. Meanwhile, Pathaan, a former RAW agent, and his senior officer Nandini, open a unit dubbed "Joint Operation and Covert Research" (JOCR), recruiting agents who were forced to retire due to trauma or injury.
Pathaan and his team head to Dubai to stop Outfit X from kidnapping two scientists. Jim fights Pathaan and manages to escape with one of the scientists. RAW joint secretary Colonel Sunil Luthra reveals that Jim was a former RAW agent and Kabir's partner: when he and his family were kidnapped by Somalian terrorists, the agency refused to negotiate with them; as a result, the terrorists killed Jim's wife and unborn child. Jim was posthumously awarded the Vir Chakra for bravery but he faked his death and now seeks vengeance against the country for abandoning him and his family.
Pathaan also learns of something called "Raktbeej" and about Rubina Mohsin, a Pakistani doctor in Spain who works with Jim. He travels to Spain and is captured by Jim's men, where he learns that Rubina is an ex-ISI agent. Rubina saves Pathaan and reveals that Raktbeej is in Moscow. They travel there to steal it before Jim does. Rubina betrays Pathaan, leaving him to captured by the Russian police. She had been working for Jim all along. Pathaan is taken to prison by train, where he is nearly murdered; he is saved by fellow agent Tiger.
Three years later, during which Pathaan was in hiding, he captures Jim's henchman, Raafe. Nandini reveals that Rubina was captured on CCTV footage in Paris. Pathaan realizes Rubina wants him to meet her there, and does so. Rubina reveals that the Raktbeej is actually a mutated version of smallpox; a deadly virus Jim forced the scientist he'd captured to create. She expresses guilt about betraying Pathaan, not knowing that her country would plan such an attack. They travel to Jim's lab in Siberia and manage to recover one orb containing the virus while Jim escapes with the other.
They take the orb to the lab to create a vaccine; however, Jim reveals that the orb has already spread the virus within the lab. The infected scientists, along with Nandini, die, and the lab is destroyed to prevent the spread of the virus. Pathaan learns from Raafe that Jim's missile is in Afghanistan. By luring Jim's soldiers into a trap, his team attacks Jim's base. Qadir is killed by Rubina and Pathaan chases after Jim with a jetpack. They crash-land into a cabin atop a cliff.
Rubina deactivates the missile containing the virus but finds that Raktbeej is actually in a passenger-bound airplane about to land in Delhi—and Jim has the detonator. Luthra remorsefully orders the plane to be blown up to prevent the virus' spread as Pathaan and Jim fight. Pathaan manages to deactivate Raktbeej and throw Jim off the cliff, resulting in his apparent death. The passenger plane lands safely and Pathaan is reinstated into RAW and made head of JOCR.
In a mid-credits scene, Pathaan and Tiger ponder retiring and suggest younger agents who can replace them. Eventually, they decide those agents aren't good enough and they'll have to keep fighting the threats themselves.
'''

# %%
Doc=nlp(Doc)

# %% [markdown]
# ## Tokenization

# %%
for token in Doc:
    print(token)
# Out:
# Pathaan
# is
# a
# 2023
# Indian
# Hindi
# -
# language
# action
# thriller
# film
# directed
# by
# Siddharth
# Anand
# and
# produced
# by
# Aditya
# Chopra
# of
# Yash
# Raj
# Films
# .
# The
# fourth
# instalment
# in
# the
# YRF
# Spy
# Universe
# ,
# it
# stars
# Shah
# Rukh
# Khan
# ,
# Deepika
# Padukone
# ,
# and
# John
# Abraham
# ,
# alongside
# Dimple
# Kapadia
# and
# Ashutosh
# Rana
# .
# Written
# by
# Shridhar
# Raghavan
# and
# Abbas
# Tyrewala
# from
# a
# story
# by
# Anand
# ,
# the
# film
# is
# about
# Pathaan
# ,
# an
# exiled
# RAW
# agent
# ,
# who
# must
# work
# with
# ISI
# agent
# Rubina
# to
# take
# down
# Jim
# ,
# a
# former
# RAW
# agent
# -
# turned
# -
# traitor
# ,
# who
# is
# planning
# to
# spread
# a
# deadly
# lab
# -
# generated
# virus
# across
# India
# .
#
#
# Principal
# photography
# for
# Pathaan
# began
# in
# November
# 2020
# in
# Mumbai
# .
# The
# film
# was
# shot
# over
# various
# locations
# in
# India
# ,
# Afghanistan
# ,
# Spain
# ,
# UAE
# ,
# Turkey
# ,
# Russia
# ,
# Italy
# and
# France
# .
# Two
# songs
# were
# composed
# by
# the
# duo
# Vishal
# –
# Shekhar
# ,
# while
# Sanchit
# Balhara
# and
# Ankit
# Balhara
# provided
# the
# score
# .
# The
# music
# video
# of
# one
# song
# ,
# "
# Besharam
# Rang
# "
# ,
# featured
# Padukone
# in
# a
# saffron
# bikini
# ,
# which
# led
# to
# protests
# by
# right
# -
# wing
# Hindutva
# groups
# and
# an
# attempt
# to
# boycott
# the
# film
# ;
# however
# ,
# the
# Central
# Board
# of
# Film
# Certification
# cleared
# the
# film
# for
# exhibition
# after
# certain
# edits
# were
# made
# to
# the
# song
# sequence
# .
# The
# film
# was
# made
# on
# an
# estimated
# production
# budget
# of
# ₹
# 225
# crore
# (
# US$
# 28
# million
# )
# with
# a
# further
# ₹
# 15
# crore
# (
# US$
# 1.9
# million
# )
# spent
# on
# print
# and
# advertising
# .
# Against
# the
# norm
# ,
# pre
# -
# release
# publicity
# was
# limited
# with
# no
# media
# interactions
# or
# public
# events
# .
#
#
# Pathaan
# was
# released
# in
# India
# on
# 25
# January
# 2023
# ,
# coinciding
# with
# the
# Republic
# Day
# weekend
# ,
# in
# IMAX
# ,
# 4DX
# and
# standard
# formats
# along
# with
# dubbed
# versions
# in
# Tamil
# and
# Telugu
# .
# It
# received
# positive
# reviews
# from
# critics
# and
# broke
# several
# Indian
# box
# -
# office
# records
# ,
# including
# the
# biggest
# opening
# day
# and
# opening
# weekend
# for
# a
# Hindi
# film
# .
# Further
# opening
# records
# were
# set
# in
# overseas
# markets
# .
# Grossing
# ₹
# 924
# crore
# (
# US$
# 120
# million
# )
# worldwide
# ,
# Pathaan
# ranks
# as
# the
# highest
# -
# grossing
# Hindi
# film
# of
# 2023
# ,
# the
# fourth
# -
# highest
# -
# grossing
# Hindi
# film
# and
# seventh
# -
# highest
# -
# grossing
# Indian
# film
# of
# all
# time
# ,
# as
# well
# as
# the
# highest
# -
# grossing
# of
# Khan
# 's
# career
# and
# Yash
# Raj
# Films
# '
# releases
# .
#
#
# In
# 2019
# ,
# the
# Indian
# Government
# revokes
# Article
# 370
# ,
# which
# grants
# special
# status
# for
# Jammu
# and
# Kashmir
# .
# The
# news
# impacts
# a
# cancer
# -
# ridden
# Pakistani
# army
# general
# ,
# Qadir
# ,
# who
# decides
# to
# exact
# vengeance
# against
# India
# .
# He
# signs
# a
# contract
# with
# Jim
# ,
# who
# leads
# "
# Outfit
# X
# "
# ,
# a
# private
# terrorist
# organization
# .
# Meanwhile
# ,
# Pathaan
# ,
# a
# former
# RAW
# agent
# ,
# and
# his
# senior
# officer
# Nandini
# ,
# open
# a
# unit
# dubbed
# "
# Joint
# Operation
# and
# Covert
# Research
# "
# (
# JOCR
# )
# ,
# recruiting
# agents
# who
# were
# forced
# to
# retire
# due
# to
# trauma
# or
# injury
# .
#
#
# Pathaan
# and
# his
# team
# head
# to
# Dubai
# to
# stop
# Outfit
# X
# from
# kidnapping
# two
# scientists
# .
# Jim
# fights
# Pathaan
# and
# manages
# to
# escape
# with
# one
# of
# the
# scientists
# .
# RAW
# joint
# secretary
# Colonel
# Sunil
# Luthra
# reveals
# that
# Jim
# was
# a
# former
# RAW
# agent
# and
# Kabir
# 's
# partner
# :
# when
# he
# and
# his
# family
# were
# kidnapped
# by
# Somalian
# terrorists
# ,
# the
# agency
# refused
# to
# negotiate
# with
# them
# ;
# as
# a
# result
# ,
# the
# terrorists
# killed
# Jim
# 's
# wife
# and
# unborn
# child
# .
# Jim
# was
# posthumously
# awarded
# the
# Vir
# Chakra
# for
# bravery
# but
# he
# faked
# his
# death
# and
# now
# seeks
# vengeance
# against
# the
# country
# for
# abandoning
# him
# and
# his
# family
# .
#
#
# Pathaan
# also
# learns
# of
# something
# called
# "
# Raktbeej
# "
# and
# about
# Rubina
# Mohsin
# ,
# a
# Pakistani
# doctor
# in
# Spain
# who
# works
# with
# Jim
# .
# He
# travels
# to
# Spain
# and
# is
# captured
# by
# Jim
# 's
# men
# ,
# where
# he
# learns
# that
# Rubina
# is
# an
# ex
# -
# ISI
# agent
# .
# Rubina
# saves
# Pathaan
# and
# reveals
# that
# Raktbeej
# is
# in
# Moscow
# .
# They
# travel
# there
# to
# steal
# it
# before
# Jim
# does
# .
# Rubina
# betrays
# Pathaan
# ,
# leaving
# him
# to
# captured
# by
# the
# Russian
# police
# .
# She
# had
# been
# working
# for
# Jim
# all
# along
# .
# Pathaan
# is
# taken
# to
# prison
# by
# train
# ,
# where
# he
# is
# nearly
# murdered
# ;
# he
# is
# saved
# by
# fellow
# agent
# Tiger
# .
#
#
# Three
# years
# later
# ,
# during
# which
# Pathaan
# was
# in
# hiding
# ,
# he
# captures
# Jim
# 's
# henchman
# ,
# Raafe
# .
# Nandini
# reveals
# that
# Rubina
# was
# captured
# on
# CCTV
# footage
# in
# Paris
# .
# Pathaan
# realizes
# Rubina
# wants
# him
# to
# meet
# her
# there
# ,
# and
# does
# so
# .
# Rubina
# reveals
# that
# the
# Raktbeej
# is
# actually
# a
# mutated
# version
# of
# smallpox
# ;
# a
# deadly
# virus
# Jim
# forced
# the
# scientist
# he
# 'd
# captured
# to
# create
# .
# She
# expresses
# guilt
# about
# betraying
# Pathaan
# ,
# not
# knowing
# that
# her
# country
# would
# plan
# such
# an
# attack
# .
# They
# travel
# to
# Jim
# 's
# lab
# in
# Siberia
# and
# manage
# to
# recover
# one
# orb
# containing
# the
# virus
# while
# Jim
# escapes
# with
# the
# other
# .
#
#
# They
# take
# the
# orb
# to
# the
# lab
# to
# create
# a
# vaccine
# ;
# however
# ,
# Jim
# reveals
# that
# the
# orb
# has
# already
# spread
# the
# virus
# within
# the
# lab
# .
# The
# infected
# scientists
# ,
# along
# with
# Nandini
# ,
# die
# ,
# and
# the
# lab
# is
# destroyed
# to
# prevent
# the
# spread
# of
# the
# virus
# .
# Pathaan
# learns
# from
# Raafe
# that
# Jim
# 's
# missile
# is
# in
# Afghanistan
# .
# By
# luring
# Jim
# 's
# soldiers
# into
# a
# trap
# ,
# his
# team
# attacks
# Jim
# 's
# base
# .
# Qadir
# is
# killed
# by
# Rubina
# and
# Pathaan
# chases
# after
# Jim
# with
# a
# jetpack
# .
# They
# crash
# -
# land
# into
# a
# cabin
# atop
# a
# cliff
# .
#
#
# Rubina
# deactivates
# the
# missile
# containing
# the
# virus
# but
# finds
# that
# Raktbeej
# is
# actually
# in
# a
# passenger
# -
# bound
# airplane
# about
# to
# land
# in
# Delhi
# —
# and
# Jim
# has
# the
# detonator
# .
# Luthra
# remorsefully
# orders
# the
# plane
# to
# be
# blown
# up
# to
# prevent
# the
# virus
# '
# spread
# as
# Pathaan
# and
# Jim
# fight
# .
# Pathaan
# manages
# to
# deactivate
# Raktbeej
# and
# throw
# Jim
# off
# the
# cliff
# ,
# resulting
# in
# his
# apparent
# death
# .
# The
# passenger
# plane
# lands
# safely
# and
# Pathaan
# is
# reinstated
# into
# RAW
# and
# made
# head
# of
# JOCR
# .
#
#
# In
# a
# mid
# -
# credits
# scene
# ,
# Pathaan
# and
# Tiger
# ponder
# retiring
# and
# suggest
# younger
# agents
# who
# can
# replace
# them
# .
# Eventually
# ,
# they
# decide
# those
# agents
# are
# n't
# good
# enough
# and
# they
# 'll
# have
# to
# keep
# fighting
# the
# threats
# themselves
# .

# %% [markdown]
# ## Number of Sentences

# %%
sent_count=0
for sent in Doc.sents:
    sent_count=sent_count+1
print('Total no of sentences:',sent_count)
# Out:
# Total no of sentences: 47

# %% [markdown]
# ## Number of Tokens

# %%
t_count=0
for token in Doc:
    t_count=t_count+1
print('The no of tokens:',t_count)
# Out:
# The no of tokens: 1093

# %% [markdown]
# ## Pos

# %%
for token in Doc:
    print(token.text,'==>',token.pos_)
# Out:
# Pathaan ==> PROPN
# is ==> AUX
# a ==> DET
# 2023 ==> NUM
# Indian ==> PROPN
# Hindi ==> PROPN
# - ==> PUNCT
# language ==> NOUN
# action ==> NOUN
# thriller ==> NOUN
# film ==> NOUN
# directed ==> VERB
# by ==> ADP
# Siddharth ==> PROPN
# Anand ==> PROPN
# and ==> CCONJ
# produced ==> VERB
# by ==> ADP
# Aditya ==> PROPN
# Chopra ==> PROPN
# of ==> ADP
# Yash ==> PROPN
# Raj ==> PROPN
# Films ==> PROPN
# . ==> PUNCT
# The ==> DET
# fourth ==> ADJ
# instalment ==> NOUN
# in ==> ADP
# the ==> DET
# YRF ==> PROPN
# Spy ==> PROPN
# Universe ==> PROPN
# , ==> PUNCT
# it ==> PRON
# stars ==> VERB
# Shah ==> PROPN
# Rukh ==> PROPN
# Khan ==> PROPN
# , ==> PUNCT
# Deepika ==> PROPN
# Padukone ==> PROPN
# , ==> PUNCT
# and ==> CCONJ
# John ==> PROPN
# Abraham ==> PROPN
# , ==> PUNCT
# alongside ==> ADP
# Dimple ==> PROPN
# Kapadia ==> PROPN
# and ==> CCONJ
# Ashutosh ==> PROPN
# Rana ==> PROPN
# . ==> PUNCT
# Written ==> VERB
# by ==> ADP
# Shridhar ==> PROPN
# Raghavan ==> PROPN
# and ==> CCONJ
# Abbas ==> PROPN
# Tyrewala ==> PROPN
# from ==> ADP
# a ==> DET
# story ==> NOUN
# by ==> ADP
# Anand ==> PROPN
# , ==> PUNCT
# the ==> DET
# film ==> NOUN
# is ==> AUX
# about ==> ADP
# Pathaan ==> PROPN
# , ==> PUNCT
# an ==> DET
# exiled ==> VERB
# RAW ==> ADJ
# agent ==> NOUN
# , ==> PUNCT
# who ==> PRON
# must ==> AUX
# work ==> VERB
# with ==> ADP
# ISI ==> PROPN
# agent ==> NOUN
# Rubina ==> PROPN
# to ==> PART
# take ==> VERB
# down ==> ADP
# Jim ==> PROPN
# , ==> PUNCT
# a ==> DET
# former ==> ADJ
# RAW ==> ADJ
# agent ==> NOUN
# - ==> PUNCT
# turned ==> VERB
# - ==> PUNCT
# traitor ==> NOUN
# , ==> PUNCT
# who ==> PRON
# is ==> AUX
# planning ==> VERB
# to ==> PART
# spread ==> VERB
# a ==> DET
# deadly ==> ADJ
# lab ==> NOUN
# - ==> PUNCT
# generated ==> VERB
# virus ==> NOUN
# across ==> ADP
# India ==> PROPN
# . ==> PUNCT
#
#  ==> SPACE
# Principal ==> PROPN
# photography ==> NOUN
# for ==> ADP
# Pathaan ==> PROPN
# began ==> VERB
# in ==> ADP
# November ==> PROPN
# 2020 ==> NUM
# in ==> ADP
# Mumbai ==> PROPN
# . ==> PUNCT
# The ==> DET
# film ==> NOUN
# was ==> AUX
# shot ==> VERB
# over ==> ADP
# various ==> ADJ
# locations ==> NOUN
# in ==> ADP
# India ==> PROPN
# , ==> PUNCT
# Afghanistan ==> PROPN
# , ==> PUNCT
# Spain ==> PROPN
# , ==> PUNCT
# UAE ==> PROPN
# , ==> PUNCT
# Turkey ==> PROPN
# , ==> PUNCT
# Russia ==> PROPN
# , ==> PUNCT
# Italy ==> PROPN
# and ==> CCONJ
# France ==> PROPN
# . ==> PUNCT
# Two ==> NUM
# songs ==> NOUN
# were ==> AUX
# composed ==> VERB
# by ==> ADP
# the ==> DET
# duo ==> ADJ
# Vishal ==> PROPN
# – ==> PUNCT
# Shekhar ==> PROPN
# , ==> PUNCT
# while ==> SCONJ
# Sanchit ==> PROPN
# Balhara ==> PROPN
# and ==> CCONJ
# Ankit ==> PROPN
# Balhara ==> PROPN
# provided ==> VERB
# the ==> DET
# score ==> NOUN
# . ==> PUNCT
# The ==> DET
# music ==> NOUN
# video ==> NOUN
# of ==> ADP
# one ==> NUM
# song ==> NOUN
# , ==> PUNCT
# " ==> PUNCT
# Besharam ==> PROPN
# Rang ==> PROPN
# " ==> PUNCT
# , ==> PUNCT
# featured ==> VERB
# Padukone ==> PROPN
# in ==> ADP
# a ==> DET
# saffron ==> NOUN
# bikini ==> NOUN
# , ==> PUNCT
# which ==> PRON
# led ==> VERB
# to ==> ADP
# protests ==> NOUN
# by ==> ADP
# right ==> ADJ
# - ==> PUNCT
# wing ==> NOUN
# Hindutva ==> PROPN
# groups ==> NOUN
# and ==> CCONJ
# an ==> DET
# attempt ==> NOUN
# to ==> PART
# boycott ==> VERB
# the ==> DET
# film ==> NOUN
# ; ==> PUNCT
# however ==> ADV
# , ==> PUNCT
# the ==> DET
# Central ==> PROPN
# Board ==> PROPN
# of ==> ADP
# Film ==> PROPN
# Certification ==> PROPN
# cleared ==> VERB
# the ==> DET
# film ==> NOUN
# for ==> ADP
# exhibition ==> NOUN
# after ==> SCONJ
# certain ==> ADJ
# edits ==> NOUN
# were ==> AUX
# made ==> VERB
# to ==> ADP
# the ==> DET
# song ==> NOUN
# sequence ==> NOUN
# . ==> PUNCT
# The ==> DET
# film ==> NOUN
# was ==> AUX
# made ==> VERB
# on ==> ADP
# an ==> DET
# estimated ==> VERB
# production ==> NOUN
# budget ==> NOUN
# of ==> ADP
# ₹ ==> PROPN
# 225 ==> NUM
# crore ==> NOUN
# ( ==> PUNCT
# US$ ==> SYM
# 28 ==> NUM
# million ==> NUM
# ) ==> PUNCT
# with ==> ADP
# a ==> DET
# further ==> ADJ
# ₹ ==> SYM
# 15 ==> NUM
# crore ==> NOUN
# ( ==> PUNCT
# US$ ==> SYM
# 1.9 ==> NUM
# million ==> NUM
# ) ==> PUNCT
# spent ==> VERB
# on ==> ADP
# print ==> NOUN
# and ==> CCONJ
# advertising ==> NOUN
# . ==> PUNCT
# Against ==> ADP
# the ==> DET
# norm ==> NOUN
# , ==> PUNCT
# pre ==> ADJ
# - ==> ADJ
# release ==> ADJ
# publicity ==> NOUN
# was ==> AUX
# limited ==> VERB
# with ==> ADP
# no ==> DET
# media ==> NOUN
# interactions ==> NOUN
# or ==> CCONJ
# public ==> ADJ
# events ==> NOUN
# . ==> PUNCT
#
#  ==> SPACE
# Pathaan ==> PROPN
# was ==> AUX
# released ==> VERB
# in ==> ADP
# India ==> PROPN
# on ==> ADP
# 25 ==> NUM
# January ==> PROPN
# 2023 ==> NUM
# , ==> PUNCT
# coinciding ==> VERB
# with ==> ADP
# the ==> DET
# Republic ==> PROPN
# Day ==> PROPN
# weekend ==> NOUN
# , ==> PUNCT
# in ==> ADP
# IMAX ==> PROPN
# , ==> PUNCT
# 4DX ==> NUM
# and ==> CCONJ
# standard ==> ADJ
# formats ==> NOUN
# along ==> ADP
# with ==> ADP
# dubbed ==> VERB
# versions ==> NOUN
# in ==> ADP
# Tamil ==> PROPN
# and ==> CCONJ
# Telugu ==> PROPN
# . ==> PUNCT
# It ==> PRON
# received ==> VERB
# positive ==> ADJ
# reviews ==> NOUN
# from ==> ADP
# critics ==> NOUN
# and ==> CCONJ
# broke ==> VERB
# several ==> ADJ
# Indian ==> ADJ
# box ==> NOUN
# - ==> PUNCT
# office ==> NOUN
# records ==> NOUN
# , ==> PUNCT
# including ==> VERB
# the ==> DET
# biggest ==> ADJ
# opening ==> NOUN
# day ==> NOUN
# and ==> CCONJ
# opening ==> NOUN
# weekend ==> NOUN
# for ==> ADP
# a ==> DET
# Hindi ==> PROPN
# film ==> NOUN
# . ==> PUNCT
# Further ==> ADJ
# opening ==> NOUN
# records ==> NOUN
# were ==> AUX
# set ==> VERB
# in ==> ADP
# overseas ==> ADJ
# markets ==> NOUN
# . ==> PUNCT
# Grossing ==> VERB
# ₹ ==> NOUN
# 924 ==> NUM
# crore ==> NOUN
# ( ==> PUNCT
# US$ ==> SYM
# 120 ==> NUM
# million ==> NUM
# ) ==> PUNCT
# worldwide ==> ADV
# , ==> PUNCT
# Pathaan ==> PROPN
# ranks ==> VERB
# as ==> ADP
# the ==> DET
# highest ==> ADV
# - ==> PUNCT
# grossing ==> VERB
# Hindi ==> PROPN
# film ==> NOUN
# of ==> ADP
# 2023 ==> NUM
# , ==> PUNCT
# the ==> DET
# fourth ==> ADV
# - ==> PUNCT
# highest ==> ADJ
# - ==> PUNCT
# grossing ==> VERB
# Hindi ==> PROPN
# film ==> NOUN
# and ==> CCONJ
# seventh ==> ADJ
# - ==> PUNCT
# highest ==> ADV
# - ==> PUNCT
# grossing ==> VERB
# Indian ==> ADJ
# film ==> NOUN
# of ==> ADP
# all ==> DET
# time ==> NOUN
# , ==> PUNCT
# as ==> ADV
# well ==> ADV
# as ==> ADP
# the ==> DET
# highest ==> ADV
# - ==> PUNCT
# grossing ==> NOUN
# of ==> ADP
# Khan ==> PROPN
# 's ==> PART
# career ==> NOUN
# and ==> CCONJ
# Yash ==> PROPN
# Raj ==> PROPN
# Films ==> PROPN
# ' ==> PART
# releases ==> NOUN
# . ==> PUNCT
#
#  ==> SPACE
# In ==> ADP
# 2019 ==> NUM
# , ==> PUNCT
# the ==> DET
# Indian ==> PROPN
# Government ==> PROPN
# revokes ==> VERB
# Article ==> NOUN
# 370 ==> NUM
# , ==> PUNCT
# which ==> PRON
# grants ==> VERB
# special ==> ADJ
# status ==> NOUN
# for ==> ADP
# Jammu ==> PROPN
# and ==> CCONJ
# Kashmir ==> PROPN
# . ==> PUNCT
# The ==> DET
# news ==> NOUN
# impacts ==> VERB
# a ==> DET
# cancer ==> NOUN
# - ==> PUNCT
# ridden ==> VERB
# Pakistani ==> ADJ
# army ==> NOUN
# general ==> NOUN
# , ==> PUNCT
# Qadir ==> PROPN
# , ==> PUNCT
# who ==> PRON
# decides ==> VERB
# to ==> PART
# exact ==> VERB
# vengeance ==> NOUN
# against ==> ADP
# India ==> PROPN
# . ==> PUNCT
# He ==> PRON
# signs ==> VERB
# a ==> DET
# contract ==> NOUN
# with ==> ADP
# Jim ==> PROPN
# , ==> PUNCT
# who ==> PRON
# leads ==> VERB
# " ==> PUNCT
# Outfit ==> VERB
# X ==> NOUN
# " ==> PUNCT
# , ==> PUNCT
# a ==> DET
# private ==> ADJ
# terrorist ==> ADJ
# organization ==> NOUN
# . ==> PUNCT
# Meanwhile ==> ADV
# , ==> PUNCT
# Pathaan ==> PROPN
# , ==> PUNCT
# a ==> DET
# former ==> ADJ
# RAW ==> ADJ
# agent ==> NOUN
# , ==> PUNCT
# and ==> CCONJ
# his ==> PRON
# senior ==> ADJ
# officer ==> NOUN
# Nandini ==> PROPN
# , ==> PUNCT
# open ==> VERB
# a ==> DET
# unit ==> NOUN
# dubbed ==> VERB
# " ==> PUNCT
# Joint ==> ADJ
# Operation ==> PROPN
# and ==> CCONJ
# Covert ==> PROPN
# Research ==> PROPN
# " ==> PUNCT
# ( ==> PUNCT
# JOCR ==> PROPN
# ) ==> PUNCT
# , ==> PUNCT
# recruiting ==> VERB
# agents ==> NOUN
# who ==> PRON
# were ==> AUX
# forced ==> VERB
# to ==> PART
# retire ==> VERB
# due ==> ADP
# to ==> ADP
# trauma ==> NOUN
# or ==> CCONJ
# injury ==> NOUN
# . ==> PUNCT
#
#  ==> SPACE
# Pathaan ==> PROPN
# and ==> CCONJ
# his ==> PRON
# team ==> NOUN
# head ==> NOUN
# to ==> ADP
# Dubai ==> PROPN
# to ==> PART
# stop ==> VERB
# Outfit ==> VERB
# X ==> NOUN
# from ==> ADP
# kidnapping ==> VERB
# two ==> NUM
# scientists ==> NOUN
# . ==> PUNCT
# Jim ==> PROPN
# fights ==> VERB
# Pathaan ==> PROPN
# and ==> CCONJ
# manages ==> VERB
# to ==> PART
# escape ==> VERB
# with ==> ADP
# one ==> NUM
# of ==> ADP
# the ==> DET
# scientists ==> NOUN
# . ==> PUNCT
# RAW ==> ADJ
# joint ==> ADJ
# secretary ==> NOUN
# Colonel ==> PROPN
# Sunil ==> PROPN
# Luthra ==> PROPN
# reveals ==> VERB
# that ==> SCONJ
# Jim ==> PROPN
# was ==> AUX
# a ==> DET
# former ==> ADJ
# RAW ==> ADJ
# agent ==> NOUN
# and ==> CCONJ
# Kabir ==> PROPN
# 's ==> PART
# partner ==> NOUN
# : ==> PUNCT
# when ==> SCONJ
# he ==> PRON
# and ==> CCONJ
# his ==> PRON
# family ==> NOUN
# were ==> AUX
# kidnapped ==> VERB
# by ==> ADP
# Somalian ==> ADJ
# terrorists ==> NOUN
# , ==> PUNCT
# the ==> DET
# agency ==> NOUN
# refused ==> VERB
# to ==> PART
# negotiate ==> VERB
# with ==> ADP
# them ==> PRON
# ; ==> PUNCT
# as ==> ADP
# a ==> DET
# result ==> NOUN
# , ==> PUNCT
# the ==> DET
# terrorists ==> NOUN
# killed ==> VERB
# Jim ==> PROPN
# 's ==> PART
# wife ==> NOUN
# and ==> CCONJ
# unborn ==> ADJ
# child ==> NOUN
# . ==> PUNCT
# Jim ==> PROPN
# was ==> AUX
# posthumously ==> ADV
# awarded ==> VERB
# the ==> DET
# Vir ==> PROPN
# Chakra ==> PROPN
# for ==> ADP
# bravery ==> NOUN
# but ==> CCONJ
# he ==> PRON
# faked ==> VERB
# his ==> PRON
# death ==> NOUN
# and ==> CCONJ
# now ==> ADV
# seeks ==> VERB
# vengeance ==> NOUN
# against ==> ADP
# the ==> DET
# country ==> NOUN
# for ==> ADP
# abandoning ==> VERB
# him ==> PRON
# and ==> CCONJ
# his ==> PRON
# family ==> NOUN
# . ==> PUNCT
#
#  ==> SPACE
# Pathaan ==> PROPN
# also ==> ADV
# learns ==> VERB
# of ==> ADP
# something ==> PRON
# called ==> VERB
# " ==> PUNCT
# Raktbeej ==> NOUN
# " ==> PUNCT
# and ==> CCONJ
# about ==> ADP
# Rubina ==> PROPN
# Mohsin ==> PROPN
# , ==> PUNCT
# a ==> DET
# Pakistani ==> ADJ
# doctor ==> NOUN
# in ==> ADP
# Spain ==> PROPN
# who ==> PRON
# works ==> VERB
# with ==> ADP
# Jim ==> PROPN
# . ==> PUNCT
# He ==> PRON
# travels ==> VERB
# to ==> ADP
# Spain ==> PROPN
# and ==> CCONJ
# is ==> AUX
# captured ==> VERB
# by ==> ADP
# Jim ==> PROPN
# 's ==> PART
# men ==> NOUN
# , ==> PUNCT
# where ==> SCONJ
# he ==> PRON
# learns ==> VERB
# that ==> SCONJ
# Rubina ==> PROPN
# is ==> AUX
# an ==> DET
# ex ==> ADJ
# - ==> ADJ
# ISI ==> ADJ
# agent ==> NOUN
# . ==> PUNCT
# Rubina ==> PROPN
# saves ==> VERB
# Pathaan ==> PROPN
# and ==> CCONJ
# reveals ==> VERB
# that ==> SCONJ
# Raktbeej ==> NOUN
# is ==> AUX
# in ==> ADP
# Moscow ==> PROPN
# . ==> PUNCT
# They ==> PRON
# travel ==> VERB
# there ==> ADV
# to ==> PART
# steal ==> VERB
# it ==> PRON
# before ==> SCONJ
# Jim ==> PROPN
# does ==> VERB
# . ==> PUNCT
# Rubina ==> PROPN
# betrays ==> VERB
# Pathaan ==> PROPN
# , ==> PUNCT
# leaving ==> VERB
# him ==> PRON
# to ==> PART
# captured ==> VERB
# by ==> ADP
# the ==> DET
# Russian ==> ADJ
# police ==> NOUN
# . ==> PUNCT
# She ==> PRON
# had ==> AUX
# been ==> AUX
# working ==> VERB
# for ==> ADP
# Jim ==> PROPN
# all ==> ADV
# along ==> ADV
# . ==> PUNCT
# Pathaan ==> PROPN
# is ==> AUX
# taken ==> VERB
# to ==> ADP
# prison ==> NOUN
# by ==> ADP
# train ==> NOUN
# , ==> PUNCT
# where ==> SCONJ
# he ==> PRON
# is ==> AUX
# nearly ==> ADV
# murdered ==> VERB
# ; ==> PUNCT
# he ==> PRON
# is ==> AUX
# saved ==> VERB
# by ==> ADP
# fellow ==> ADJ
# agent ==> NOUN
# Tiger ==> PROPN
# . ==> PUNCT
#
#  ==> SPACE
# Three ==> NUM
# years ==> NOUN
# later ==> ADV
# , ==> PUNCT
# during ==> ADP
# which ==> PRON
# Pathaan ==> PROPN
# was ==> AUX
# in ==> ADP
# hiding ==> NOUN
# , ==> PUNCT
# he ==> PRON
# captures ==> VERB
# Jim ==> PROPN
# 's ==> PART
# henchman ==> NOUN
# , ==> PUNCT
# Raafe ==> PROPN
# . ==> PUNCT
# Nandini ==> PROPN
# reveals ==> VERB
# that ==> SCONJ
# Rubina ==> PROPN
# was ==> AUX
# captured ==> VERB
# on ==> ADP
# CCTV ==> PROPN
# footage ==> NOUN
# in ==> ADP
# Paris ==> PROPN
# . ==> PUNCT
# Pathaan ==> PROPN
# realizes ==> VERB
# Rubina ==> PROPN
# wants ==> VERB
# him ==> PRON
# to ==> PART
# meet ==> VERB
# her ==> PRON
# there ==> ADV
# , ==> PUNCT
# and ==> CCONJ
# does ==> VERB
# so ==> ADV
# . ==> PUNCT
# Rubina ==> PROPN
# reveals ==> VERB
# that ==> SCONJ
# the ==> DET
# Raktbeej ==> NOUN
# is ==> AUX
# actually ==> ADV
# a ==> DET
# mutated ==> VERB
# version ==> NOUN
# of ==> ADP
# smallpox ==> NOUN
# ; ==> PUNCT
# a ==> DET
# deadly ==> ADJ
# virus ==> NOUN
# Jim ==> PROPN
# forced ==> VERB
# the ==> DET
# scientist ==> NOUN
# he ==> PRON
# 'd ==> AUX
# captured ==> VERB
# to ==> PART
# create ==> VERB
# . ==> PUNCT
# She ==> PRON
# expresses ==> VERB
# guilt ==> NOUN
# about ==> ADP
# betraying ==> VERB
# Pathaan ==> PROPN
# , ==> PUNCT
# not ==> PART
# knowing ==> VERB
# that ==> SCONJ
# her ==> PRON
# country ==> NOUN
# would ==> AUX
# plan ==> VERB
# such ==> DET
# an ==> DET
# attack ==> NOUN
# . ==> PUNCT
# They ==> PRON
# travel ==> VERB
# to ==> ADP
# Jim ==> PROPN
# 's ==> PART
# lab ==> NOUN
# in ==> ADP
# Siberia ==> PROPN
# and ==> CCONJ
# manage ==> VERB
# to ==> PART
# recover ==> VERB
# one ==> NUM
# orb ==> NOUN
# containing ==> VERB
# the ==> DET
# virus ==> NOUN
# while ==> SCONJ
# Jim ==> PROPN
# escapes ==> VERB
# with ==> ADP
# the ==> DET
# other ==> ADJ
# . ==> PUNCT
#
#  ==> SPACE
# They ==> PRON
# take ==> VERB
# the ==> DET
# orb ==> NOUN
# to ==> ADP
# the ==> DET
# lab ==> NOUN
# to ==> PART
# create ==> VERB
# a ==> DET
# vaccine ==> NOUN
# ; ==> PUNCT
# however ==> ADV
# , ==> PUNCT
# Jim ==> PROPN
# reveals ==> VERB
# that ==> SCONJ
# the ==> DET
# orb ==> NOUN
# has ==> AUX
# already ==> ADV
# spread ==> VERB
# the ==> DET
# virus ==> NOUN
# within ==> ADP
# the ==> DET
# lab ==> NOUN
# . ==> PUNCT
# The ==> DET
# infected ==> ADJ
# scientists ==> NOUN
# , ==> PUNCT
# along ==> ADP
# with ==> ADP
# Nandini ==> PROPN
# , ==> PUNCT
# die ==> NOUN
# , ==> PUNCT
# and ==> CCONJ
# the ==> DET
# lab ==> NOUN
# is ==> AUX
# destroyed ==> VERB
# to ==> PART
# prevent ==> VERB
# the ==> DET
# spread ==> NOUN
# of ==> ADP
# the ==> DET
# virus ==> NOUN
# . ==> PUNCT
# Pathaan ==> NOUN
# learns ==> VERB
# from ==> ADP
# Raafe ==> PROPN
# that ==> SCONJ
# Jim ==> PROPN
# 's ==> PART
# missile ==> NOUN
# is ==> AUX
# in ==> ADP
# Afghanistan ==> PROPN
# . ==> PUNCT
# By ==> ADP
# luring ==> VERB
# Jim ==> PROPN
# 's ==> PART
# soldiers ==> NOUN
# into ==> ADP
# a ==> DET
# trap ==> NOUN
# , ==> PUNCT
# his ==> PRON
# team ==> NOUN
# attacks ==> VERB
# Jim ==> PROPN
# 's ==> PART
# base ==> NOUN
# . ==> PUNCT
# Qadir ==> PROPN
# is ==> AUX
# killed ==> VERB
# by ==> ADP
# Rubina ==> PROPN
# and ==> CCONJ
# Pathaan ==> PROPN
# chases ==> NOUN
# after ==> ADP
# Jim ==> PROPN
# with ==> ADP
# a ==> DET
# jetpack ==> NOUN
# . ==> PUNCT
# They ==> PRON
# crash ==> NOUN
# - ==> PUNCT
# land ==> NOUN
# into ==> ADP
# a ==> DET
# cabin ==> NOUN
# atop ==> ADP
# a ==> DET
# cliff ==> NOUN
# . ==> PUNCT
#
#  ==> SPACE
# Rubina ==> PROPN
# deactivates ==> VERB
# the ==> DET
# missile ==> NOUN
# containing ==> VERB
# the ==> DET
# virus ==> NOUN
# but ==> CCONJ
# finds ==> VERB
# that ==> SCONJ
# Raktbeej ==> NOUN
# is ==> AUX
# actually ==> ADV
# in ==> ADP
# a ==> DET
# passenger ==> NOUN
# - ==> PUNCT
# bound ==> VERB
# airplane ==> NOUN
# about ==> ADP
# to ==> PART
# land ==> VERB
# in ==> ADP
# Delhi ==> PROPN
# — ==> PUNCT
# and ==> CCONJ
# Jim ==> PROPN
# has ==> VERB
# the ==> DET
# detonator ==> NOUN
# . ==> PUNCT
# Luthra ==> PROPN
# remorsefully ==> ADV
# orders ==> VERB
# the ==> DET
# plane ==> NOUN
# to ==> PART
# be ==> AUX
# blown ==> VERB
# up ==> ADP
# to ==> PART
# prevent ==> VERB
# the ==> DET
# virus ==> NOUN
# ' ==> PART
# spread ==> NOUN
# as ==> ADP
# Pathaan ==> PROPN
# and ==> CCONJ
# Jim ==> PROPN
# fight ==> NOUN
# . ==> PUNCT
# Pathaan ==> NOUN
# manages ==> VERB
# to ==> PART
# deactivate ==> VERB
# Raktbeej ==> NOUN
# and ==> CCONJ
# throw ==> VERB
# Jim ==> PROPN
# off ==> ADP
# the ==> DET
# cliff ==> NOUN
# , ==> PUNCT
# resulting ==> VERB
# in ==> ADP
# his ==> PRON
# apparent ==> ADJ
# death ==> NOUN
# . ==> PUNCT
# The ==> DET
# passenger ==> NOUN
# plane ==> NOUN
# lands ==> VERB
# safely ==> ADV
# and ==> CCONJ
# Pathaan ==> PROPN
# is ==> AUX
# reinstated ==> VERB
# into ==> ADP
# RAW ==> PROPN
# and ==> CCONJ
# made ==> VERB
# head ==> NOUN
# of ==> ADP
# JOCR ==> PROPN
# . ==> PUNCT
#
#  ==> SPACE
# In ==> ADP
# a ==> DET
# mid ==> ADJ
# - ==> NOUN
# credits ==> NOUN
# scene ==> NOUN
# , ==> PUNCT
# Pathaan ==> PROPN
# and ==> CCONJ
# Tiger ==> PROPN
# ponder ==> NOUN
# retiring ==> VERB
# and ==> CCONJ
# suggest ==> VERB
# younger ==> ADJ
# agents ==> NOUN
# who ==> PRON
# can ==> AUX
# replace ==> VERB
# them ==> PRON
# . ==> PUNCT
# Eventually ==> ADV
# , ==> PUNCT
# they ==> PRON
# decide ==> VERB
# those ==> DET
# agents ==> NOUN
# are ==> AUX
# n't ==> PART
# good ==> ADJ
# enough ==> ADV
# and ==> CCONJ
# they ==> PRON
# 'll ==> AUX
# have ==> VERB
# to ==> PART
# keep ==> VERB
# fighting ==> VERB
# the ==> DET
# threats ==> NOUN
# themselves ==> PRON
# . ==> PUNCT
#
#  ==> SPACE

# %% [markdown]
# ## Not a stopword

# %%
for token in Doc:
    print(token,'==>',token.pos_,'==>',token.is_stop)
# Out:
# Pathaan ==> PROPN ==> False
# is ==> AUX ==> True
# a ==> DET ==> True
# 2023 ==> NUM ==> False
# Indian ==> PROPN ==> False
# Hindi ==> PROPN ==> False
# - ==> PUNCT ==> False
# language ==> NOUN ==> False
# action ==> NOUN ==> False
# thriller ==> NOUN ==> False
# film ==> NOUN ==> False
# directed ==> VERB ==> False
# by ==> ADP ==> True
# Siddharth ==> PROPN ==> False
# Anand ==> PROPN ==> False
# and ==> CCONJ ==> True
# produced ==> VERB ==> False
# by ==> ADP ==> True
# Aditya ==> PROPN ==> False
# Chopra ==> PROPN ==> False
# of ==> ADP ==> True
# Yash ==> PROPN ==> False
# Raj ==> PROPN ==> False
# Films ==> PROPN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> True
# fourth ==> ADJ ==> False
# instalment ==> NOUN ==> False
# in ==> ADP ==> True
# the ==> DET ==> True
# YRF ==> PROPN ==> False
# Spy ==> PROPN ==> False
# Universe ==> PROPN ==> False
# , ==> PUNCT ==> False
# it ==> PRON ==> True
# stars ==> VERB ==> False
# Shah ==> PROPN ==> False
# Rukh ==> PROPN ==> False
# Khan ==> PROPN ==> False
# , ==> PUNCT ==> False
# Deepika ==> PROPN ==> False
# Padukone ==> PROPN ==> False
# , ==> PUNCT ==> False
# and ==> CCONJ ==> True
# John ==> PROPN ==> False
# Abraham ==> PROPN ==> False
# , ==> PUNCT ==> False
# alongside ==> ADP ==> False
# Dimple ==> PROPN ==> False
# Kapadia ==> PROPN ==> False
# and ==> CCONJ ==> True
# Ashutosh ==> PROPN ==> False
# Rana ==> PROPN ==> False
# . ==> PUNCT ==> False
# Written ==> VERB ==> False
# by ==> ADP ==> True
# Shridhar ==> PROPN ==> False
# Raghavan ==> PROPN ==> False
# and ==> CCONJ ==> True
# Abbas ==> PROPN ==> False
# Tyrewala ==> PROPN ==> False
# from ==> ADP ==> True
# a ==> DET ==> True
# story ==> NOUN ==> False
# by ==> ADP ==> True
# Anand ==> PROPN ==> False
# , ==> PUNCT ==> False
# the ==> DET ==> True
# film ==> NOUN ==> False
# is ==> AUX ==> True
# about ==> ADP ==> True
# Pathaan ==> PROPN ==> False
# , ==> PUNCT ==> False
# an ==> DET ==> True
# exiled ==> VERB ==> False
# RAW ==> ADJ ==> False
# agent ==> NOUN ==> False
# , ==> PUNCT ==> False
# who ==> PRON ==> True
# must ==> AUX ==> True
# work ==> VERB ==> False
# with ==> ADP ==> True
# ISI ==> PROPN ==> False
# agent ==> NOUN ==> False
# Rubina ==> PROPN ==> False
# to ==> PART ==> True
# take ==> VERB ==> True
# down ==> ADP ==> True
# Jim ==> PROPN ==> False
# , ==> PUNCT ==> False
# a ==> DET ==> True
# former ==> ADJ ==> True
# RAW ==> ADJ ==> False
# agent ==> NOUN ==> False
# - ==> PUNCT ==> False
# turned ==> VERB ==> False
# - ==> PUNCT ==> False
# traitor ==> NOUN ==> False
# , ==> PUNCT ==> False
# who ==> PRON ==> True
# is ==> AUX ==> True
# planning ==> VERB ==> False
# to ==> PART ==> True
# spread ==> VERB ==> False
# a ==> DET ==> True
# deadly ==> ADJ ==> False
# lab ==> NOUN ==> False
# - ==> PUNCT ==> False
# generated ==> VERB ==> False
# virus ==> NOUN ==> False
# across ==> ADP ==> True
# India ==> PROPN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# Principal ==> PROPN ==> False
# photography ==> NOUN ==> False
# for ==> ADP ==> True
# Pathaan ==> PROPN ==> False
# began ==> VERB ==> False
# in ==> ADP ==> True
# November ==> PROPN ==> False
# 2020 ==> NUM ==> False
# in ==> ADP ==> True
# Mumbai ==> PROPN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> True
# film ==> NOUN ==> False
# was ==> AUX ==> True
# shot ==> VERB ==> False
# over ==> ADP ==> True
# various ==> ADJ ==> True
# locations ==> NOUN ==> False
# in ==> ADP ==> True
# India ==> PROPN ==> False
# , ==> PUNCT ==> False
# Afghanistan ==> PROPN ==> False
# , ==> PUNCT ==> False
# Spain ==> PROPN ==> False
# , ==> PUNCT ==> False
# UAE ==> PROPN ==> False
# , ==> PUNCT ==> False
# Turkey ==> PROPN ==> False
# , ==> PUNCT ==> False
# Russia ==> PROPN ==> False
# , ==> PUNCT ==> False
# Italy ==> PROPN ==> False
# and ==> CCONJ ==> True
# France ==> PROPN ==> False
# . ==> PUNCT ==> False
# Two ==> NUM ==> True
# songs ==> NOUN ==> False
# were ==> AUX ==> True
# composed ==> VERB ==> False
# by ==> ADP ==> True
# the ==> DET ==> True
# duo ==> ADJ ==> False
# Vishal ==> PROPN ==> False
# – ==> PUNCT ==> False
# Shekhar ==> PROPN ==> False
# , ==> PUNCT ==> False
# while ==> SCONJ ==> True
# Sanchit ==> PROPN ==> False
# Balhara ==> PROPN ==> False
# and ==> CCONJ ==> True
# Ankit ==> PROPN ==> False
# Balhara ==> PROPN ==> False
# provided ==> VERB ==> False
# the ==> DET ==> True
# score ==> NOUN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> True
# music ==> NOUN ==> False
# video ==> NOUN ==> False
# of ==> ADP ==> True
# one ==> NUM ==> True
# song ==> NOUN ==> False
# , ==> PUNCT ==> False
# " ==> PUNCT ==> False
# Besharam ==> PROPN ==> False
# Rang ==> PROPN ==> False
# " ==> PUNCT ==> False
# , ==> PUNCT ==> False
# featured ==> VERB ==> False
# Padukone ==> PROPN ==> False
# in ==> ADP ==> True
# a ==> DET ==> True
# saffron ==> NOUN ==> False
# bikini ==> NOUN ==> False
# , ==> PUNCT ==> False
# which ==> PRON ==> True
# led ==> VERB ==> False
# to ==> ADP ==> True
# protests ==> NOUN ==> False
# by ==> ADP ==> True
# right ==> ADJ ==> False
# - ==> PUNCT ==> False
# wing ==> NOUN ==> False
# Hindutva ==> PROPN ==> False
# groups ==> NOUN ==> False
# and ==> CCONJ ==> True
# an ==> DET ==> True
# attempt ==> NOUN ==> False
# to ==> PART ==> True
# boycott ==> VERB ==> False
# the ==> DET ==> True
# film ==> NOUN ==> False
# ; ==> PUNCT ==> False
# however ==> ADV ==> True
# , ==> PUNCT ==> False
# the ==> DET ==> True
# Central ==> PROPN ==> False
# Board ==> PROPN ==> False
# of ==> ADP ==> True
# Film ==> PROPN ==> False
# Certification ==> PROPN ==> False
# cleared ==> VERB ==> False
# the ==> DET ==> True
# film ==> NOUN ==> False
# for ==> ADP ==> True
# exhibition ==> NOUN ==> False
# after ==> SCONJ ==> True
# certain ==> ADJ ==> False
# edits ==> NOUN ==> False
# were ==> AUX ==> True
# made ==> VERB ==> True
# to ==> ADP ==> True
# the ==> DET ==> True
# song ==> NOUN ==> False
# sequence ==> NOUN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> True
# film ==> NOUN ==> False
# was ==> AUX ==> True
# made ==> VERB ==> True
# on ==> ADP ==> True
# an ==> DET ==> True
# estimated ==> VERB ==> False
# production ==> NOUN ==> False
# budget ==> NOUN ==> False
# of ==> ADP ==> True
# ₹ ==> PROPN ==> False
# 225 ==> NUM ==> False
# crore ==> NOUN ==> False
# ( ==> PUNCT ==> False
# US$ ==> SYM ==> False
# 28 ==> NUM ==> False
# million ==> NUM ==> False
# ) ==> PUNCT ==> False
# with ==> ADP ==> True
# a ==> DET ==> True
# further ==> ADJ ==> True
# ₹ ==> SYM ==> False
# 15 ==> NUM ==> False
# crore ==> NOUN ==> False
# ( ==> PUNCT ==> False
# US$ ==> SYM ==> False
# 1.9 ==> NUM ==> False
# million ==> NUM ==> False
# ) ==> PUNCT ==> False
# spent ==> VERB ==> False
# on ==> ADP ==> True
# print ==> NOUN ==> False
# and ==> CCONJ ==> True
# advertising ==> NOUN ==> False
# . ==> PUNCT ==> False
# Against ==> ADP ==> True
# the ==> DET ==> True
# norm ==> NOUN ==> False
# , ==> PUNCT ==> False
# pre ==> ADJ ==> False
# - ==> ADJ ==> False
# release ==> ADJ ==> False
# publicity ==> NOUN ==> False
# was ==> AUX ==> True
# limited ==> VERB ==> False
# with ==> ADP ==> True
# no ==> DET ==> True
# media ==> NOUN ==> False
# interactions ==> NOUN ==> False
# or ==> CCONJ ==> True
# public ==> ADJ ==> False
# events ==> NOUN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# Pathaan ==> PROPN ==> False
# was ==> AUX ==> True
# released ==> VERB ==> False
# in ==> ADP ==> True
# India ==> PROPN ==> False
# on ==> ADP ==> True
# 25 ==> NUM ==> False
# January ==> PROPN ==> False
# 2023 ==> NUM ==> False
# , ==> PUNCT ==> False
# coinciding ==> VERB ==> False
# with ==> ADP ==> True
# the ==> DET ==> True
# Republic ==> PROPN ==> False
# Day ==> PROPN ==> False
# weekend ==> NOUN ==> False
# , ==> PUNCT ==> False
# in ==> ADP ==> True
# IMAX ==> PROPN ==> False
# , ==> PUNCT ==> False
# 4DX ==> NUM ==> False
# and ==> CCONJ ==> True
# standard ==> ADJ ==> False
# formats ==> NOUN ==> False
# along ==> ADP ==> True
# with ==> ADP ==> True
# dubbed ==> VERB ==> False
# versions ==> NOUN ==> False
# in ==> ADP ==> True
# Tamil ==> PROPN ==> False
# and ==> CCONJ ==> True
# Telugu ==> PROPN ==> False
# . ==> PUNCT ==> False
# It ==> PRON ==> True
# received ==> VERB ==> False
# positive ==> ADJ ==> False
# reviews ==> NOUN ==> False
# from ==> ADP ==> True
# critics ==> NOUN ==> False
# and ==> CCONJ ==> True
# broke ==> VERB ==> False
# several ==> ADJ ==> True
# Indian ==> ADJ ==> False
# box ==> NOUN ==> False
# - ==> PUNCT ==> False
# office ==> NOUN ==> False
# records ==> NOUN ==> False
# , ==> PUNCT ==> False
# including ==> VERB ==> False
# the ==> DET ==> True
# biggest ==> ADJ ==> False
# opening ==> NOUN ==> False
# day ==> NOUN ==> False
# and ==> CCONJ ==> True
# opening ==> NOUN ==> False
# weekend ==> NOUN ==> False
# for ==> ADP ==> True
# a ==> DET ==> True
# Hindi ==> PROPN ==> False
# film ==> NOUN ==> False
# . ==> PUNCT ==> False
# Further ==> ADJ ==> True
# opening ==> NOUN ==> False
# records ==> NOUN ==> False
# were ==> AUX ==> True
# set ==> VERB ==> False
# in ==> ADP ==> True
# overseas ==> ADJ ==> False
# markets ==> NOUN ==> False
# . ==> PUNCT ==> False
# Grossing ==> VERB ==> False
# ₹ ==> NOUN ==> False
# 924 ==> NUM ==> False
# crore ==> NOUN ==> False
# ( ==> PUNCT ==> False
# US$ ==> SYM ==> False
# 120 ==> NUM ==> False
# million ==> NUM ==> False
# ) ==> PUNCT ==> False
# worldwide ==> ADV ==> False
# , ==> PUNCT ==> False
# Pathaan ==> PROPN ==> False
# ranks ==> VERB ==> False
# as ==> ADP ==> True
# the ==> DET ==> True
# highest ==> ADV ==> False
# - ==> PUNCT ==> False
# grossing ==> VERB ==> False
# Hindi ==> PROPN ==> False
# film ==> NOUN ==> False
# of ==> ADP ==> True
# 2023 ==> NUM ==> False
# , ==> PUNCT ==> False
# the ==> DET ==> True
# fourth ==> ADV ==> False
# - ==> PUNCT ==> False
# highest ==> ADJ ==> False
# - ==> PUNCT ==> False
# grossing ==> VERB ==> False
# Hindi ==> PROPN ==> False
# film ==> NOUN ==> False
# and ==> CCONJ ==> True
# seventh ==> ADJ ==> False
# - ==> PUNCT ==> False
# highest ==> ADV ==> False
# - ==> PUNCT ==> False
# grossing ==> VERB ==> False
# Indian ==> ADJ ==> False
# film ==> NOUN ==> False
# of ==> ADP ==> True
# all ==> DET ==> True
# time ==> NOUN ==> False
# , ==> PUNCT ==> False
# as ==> ADV ==> True
# well ==> ADV ==> True
# as ==> ADP ==> True
# the ==> DET ==> True
# highest ==> ADV ==> False
# - ==> PUNCT ==> False
# grossing ==> NOUN ==> False
# of ==> ADP ==> True
# Khan ==> PROPN ==> False
# 's ==> PART ==> True
# career ==> NOUN ==> False
# and ==> CCONJ ==> True
# Yash ==> PROPN ==> False
# Raj ==> PROPN ==> False
# Films ==> PROPN ==> False
# ' ==> PART ==> False
# releases ==> NOUN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# In ==> ADP ==> True
# 2019 ==> NUM ==> False
# , ==> PUNCT ==> False
# the ==> DET ==> True
# Indian ==> PROPN ==> False
# Government ==> PROPN ==> False
# revokes ==> VERB ==> False
# Article ==> NOUN ==> False
# 370 ==> NUM ==> False
# , ==> PUNCT ==> False
# which ==> PRON ==> True
# grants ==> VERB ==> False
# special ==> ADJ ==> False
# status ==> NOUN ==> False
# for ==> ADP ==> True
# Jammu ==> PROPN ==> False
# and ==> CCONJ ==> True
# Kashmir ==> PROPN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> True
# news ==> NOUN ==> False
# impacts ==> VERB ==> False
# a ==> DET ==> True
# cancer ==> NOUN ==> False
# - ==> PUNCT ==> False
# ridden ==> VERB ==> False
# Pakistani ==> ADJ ==> False
# army ==> NOUN ==> False
# general ==> NOUN ==> False
# , ==> PUNCT ==> False
# Qadir ==> PROPN ==> False
# , ==> PUNCT ==> False
# who ==> PRON ==> True
# decides ==> VERB ==> False
# to ==> PART ==> True
# exact ==> VERB ==> False
# vengeance ==> NOUN ==> False
# against ==> ADP ==> True
# India ==> PROPN ==> False
# . ==> PUNCT ==> False
# He ==> PRON ==> True
# signs ==> VERB ==> False
# a ==> DET ==> True
# contract ==> NOUN ==> False
# with ==> ADP ==> True
# Jim ==> PROPN ==> False
# , ==> PUNCT ==> False
# who ==> PRON ==> True
# leads ==> VERB ==> False
# " ==> PUNCT ==> False
# Outfit ==> VERB ==> False
# X ==> NOUN ==> False
# " ==> PUNCT ==> False
# , ==> PUNCT ==> False
# a ==> DET ==> True
# private ==> ADJ ==> False
# terrorist ==> ADJ ==> False
# organization ==> NOUN ==> False
# . ==> PUNCT ==> False
# Meanwhile ==> ADV ==> True
# , ==> PUNCT ==> False
# Pathaan ==> PROPN ==> False
# , ==> PUNCT ==> False
# a ==> DET ==> True
# former ==> ADJ ==> True
# RAW ==> ADJ ==> False
# agent ==> NOUN ==> False
# , ==> PUNCT ==> False
# and ==> CCONJ ==> True
# his ==> PRON ==> True
# senior ==> ADJ ==> False
# officer ==> NOUN ==> False
# Nandini ==> PROPN ==> False
# , ==> PUNCT ==> False
# open ==> VERB ==> False
# a ==> DET ==> True
# unit ==> NOUN ==> False
# dubbed ==> VERB ==> False
# " ==> PUNCT ==> False
# Joint ==> ADJ ==> False
# Operation ==> PROPN ==> False
# and ==> CCONJ ==> True
# Covert ==> PROPN ==> False
# Research ==> PROPN ==> False
# " ==> PUNCT ==> False
# ( ==> PUNCT ==> False
# JOCR ==> PROPN ==> False
# ) ==> PUNCT ==> False
# , ==> PUNCT ==> False
# recruiting ==> VERB ==> False
# agents ==> NOUN ==> False
# who ==> PRON ==> True
# were ==> AUX ==> True
# forced ==> VERB ==> False
# to ==> PART ==> True
# retire ==> VERB ==> False
# due ==> ADP ==> True
# to ==> ADP ==> True
# trauma ==> NOUN ==> False
# or ==> CCONJ ==> True
# injury ==> NOUN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> True
# his ==> PRON ==> True
# team ==> NOUN ==> False
# head ==> NOUN ==> False
# to ==> ADP ==> True
# Dubai ==> PROPN ==> False
# to ==> PART ==> True
# stop ==> VERB ==> False
# Outfit ==> VERB ==> False
# X ==> NOUN ==> False
# from ==> ADP ==> True
# kidnapping ==> VERB ==> False
# two ==> NUM ==> True
# scientists ==> NOUN ==> False
# . ==> PUNCT ==> False
# Jim ==> PROPN ==> False
# fights ==> VERB ==> False
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> True
# manages ==> VERB ==> False
# to ==> PART ==> True
# escape ==> VERB ==> False
# with ==> ADP ==> True
# one ==> NUM ==> True
# of ==> ADP ==> True
# the ==> DET ==> True
# scientists ==> NOUN ==> False
# . ==> PUNCT ==> False
# RAW ==> ADJ ==> False
# joint ==> ADJ ==> False
# secretary ==> NOUN ==> False
# Colonel ==> PROPN ==> False
# Sunil ==> PROPN ==> False
# Luthra ==> PROPN ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> True
# Jim ==> PROPN ==> False
# was ==> AUX ==> True
# a ==> DET ==> True
# former ==> ADJ ==> True
# RAW ==> ADJ ==> False
# agent ==> NOUN ==> False
# and ==> CCONJ ==> True
# Kabir ==> PROPN ==> False
# 's ==> PART ==> True
# partner ==> NOUN ==> False
# : ==> PUNCT ==> False
# when ==> SCONJ ==> True
# he ==> PRON ==> True
# and ==> CCONJ ==> True
# his ==> PRON ==> True
# family ==> NOUN ==> False
# were ==> AUX ==> True
# kidnapped ==> VERB ==> False
# by ==> ADP ==> True
# Somalian ==> ADJ ==> False
# terrorists ==> NOUN ==> False
# , ==> PUNCT ==> False
# the ==> DET ==> True
# agency ==> NOUN ==> False
# refused ==> VERB ==> False
# to ==> PART ==> True
# negotiate ==> VERB ==> False
# with ==> ADP ==> True
# them ==> PRON ==> True
# ; ==> PUNCT ==> False
# as ==> ADP ==> True
# a ==> DET ==> True
# result ==> NOUN ==> False
# , ==> PUNCT ==> False
# the ==> DET ==> True
# terrorists ==> NOUN ==> False
# killed ==> VERB ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> True
# wife ==> NOUN ==> False
# and ==> CCONJ ==> True
# unborn ==> ADJ ==> False
# child ==> NOUN ==> False
# . ==> PUNCT ==> False
# Jim ==> PROPN ==> False
# was ==> AUX ==> True
# posthumously ==> ADV ==> False
# awarded ==> VERB ==> False
# the ==> DET ==> True
# Vir ==> PROPN ==> False
# Chakra ==> PROPN ==> False
# for ==> ADP ==> True
# bravery ==> NOUN ==> False
# but ==> CCONJ ==> True
# he ==> PRON ==> True
# faked ==> VERB ==> False
# his ==> PRON ==> True
# death ==> NOUN ==> False
# and ==> CCONJ ==> True
# now ==> ADV ==> True
# seeks ==> VERB ==> False
# vengeance ==> NOUN ==> False
# against ==> ADP ==> True
# the ==> DET ==> True
# country ==> NOUN ==> False
# for ==> ADP ==> True
# abandoning ==> VERB ==> False
# him ==> PRON ==> True
# and ==> CCONJ ==> True
# his ==> PRON ==> True
# family ==> NOUN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# Pathaan ==> PROPN ==> False
# also ==> ADV ==> True
# learns ==> VERB ==> False
# of ==> ADP ==> True
# something ==> PRON ==> True
# called ==> VERB ==> False
# " ==> PUNCT ==> False
# Raktbeej ==> NOUN ==> False
# " ==> PUNCT ==> False
# and ==> CCONJ ==> True
# about ==> ADP ==> True
# Rubina ==> PROPN ==> False
# Mohsin ==> PROPN ==> False
# , ==> PUNCT ==> False
# a ==> DET ==> True
# Pakistani ==> ADJ ==> False
# doctor ==> NOUN ==> False
# in ==> ADP ==> True
# Spain ==> PROPN ==> False
# who ==> PRON ==> True
# works ==> VERB ==> False
# with ==> ADP ==> True
# Jim ==> PROPN ==> False
# . ==> PUNCT ==> False
# He ==> PRON ==> True
# travels ==> VERB ==> False
# to ==> ADP ==> True
# Spain ==> PROPN ==> False
# and ==> CCONJ ==> True
# is ==> AUX ==> True
# captured ==> VERB ==> False
# by ==> ADP ==> True
# Jim ==> PROPN ==> False
# 's ==> PART ==> True
# men ==> NOUN ==> False
# , ==> PUNCT ==> False
# where ==> SCONJ ==> True
# he ==> PRON ==> True
# learns ==> VERB ==> False
# that ==> SCONJ ==> True
# Rubina ==> PROPN ==> False
# is ==> AUX ==> True
# an ==> DET ==> True
# ex ==> ADJ ==> False
# - ==> ADJ ==> False
# ISI ==> ADJ ==> False
# agent ==> NOUN ==> False
# . ==> PUNCT ==> False
# Rubina ==> PROPN ==> False
# saves ==> VERB ==> False
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> True
# reveals ==> VERB ==> False
# that ==> SCONJ ==> True
# Raktbeej ==> NOUN ==> False
# is ==> AUX ==> True
# in ==> ADP ==> True
# Moscow ==> PROPN ==> False
# . ==> PUNCT ==> False
# They ==> PRON ==> True
# travel ==> VERB ==> False
# there ==> ADV ==> True
# to ==> PART ==> True
# steal ==> VERB ==> False
# it ==> PRON ==> True
# before ==> SCONJ ==> True
# Jim ==> PROPN ==> False
# does ==> VERB ==> True
# . ==> PUNCT ==> False
# Rubina ==> PROPN ==> False
# betrays ==> VERB ==> False
# Pathaan ==> PROPN ==> False
# , ==> PUNCT ==> False
# leaving ==> VERB ==> False
# him ==> PRON ==> True
# to ==> PART ==> True
# captured ==> VERB ==> False
# by ==> ADP ==> True
# the ==> DET ==> True
# Russian ==> ADJ ==> False
# police ==> NOUN ==> False
# . ==> PUNCT ==> False
# She ==> PRON ==> True
# had ==> AUX ==> True
# been ==> AUX ==> True
# working ==> VERB ==> False
# for ==> ADP ==> True
# Jim ==> PROPN ==> False
# all ==> ADV ==> True
# along ==> ADV ==> True
# . ==> PUNCT ==> False
# Pathaan ==> PROPN ==> False
# is ==> AUX ==> True
# taken ==> VERB ==> False
# to ==> ADP ==> True
# prison ==> NOUN ==> False
# by ==> ADP ==> True
# train ==> NOUN ==> False
# , ==> PUNCT ==> False
# where ==> SCONJ ==> True
# he ==> PRON ==> True
# is ==> AUX ==> True
# nearly ==> ADV ==> False
# murdered ==> VERB ==> False
# ; ==> PUNCT ==> False
# he ==> PRON ==> True
# is ==> AUX ==> True
# saved ==> VERB ==> False
# by ==> ADP ==> True
# fellow ==> ADJ ==> False
# agent ==> NOUN ==> False
# Tiger ==> PROPN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# Three ==> NUM ==> True
# years ==> NOUN ==> False
# later ==> ADV ==> False
# , ==> PUNCT ==> False
# during ==> ADP ==> True
# which ==> PRON ==> True
# Pathaan ==> PROPN ==> False
# was ==> AUX ==> True
# in ==> ADP ==> True
# hiding ==> NOUN ==> False
# , ==> PUNCT ==> False
# he ==> PRON ==> True
# captures ==> VERB ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> True
# henchman ==> NOUN ==> False
# , ==> PUNCT ==> False
# Raafe ==> PROPN ==> False
# . ==> PUNCT ==> False
# Nandini ==> PROPN ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> True
# Rubina ==> PROPN ==> False
# was ==> AUX ==> True
# captured ==> VERB ==> False
# on ==> ADP ==> True
# CCTV ==> PROPN ==> False
# footage ==> NOUN ==> False
# in ==> ADP ==> True
# Paris ==> PROPN ==> False
# . ==> PUNCT ==> False
# Pathaan ==> PROPN ==> False
# realizes ==> VERB ==> False
# Rubina ==> PROPN ==> False
# wants ==> VERB ==> False
# him ==> PRON ==> True
# to ==> PART ==> True
# meet ==> VERB ==> False
# her ==> PRON ==> True
# there ==> ADV ==> True
# , ==> PUNCT ==> False
# and ==> CCONJ ==> True
# does ==> VERB ==> True
# so ==> ADV ==> True
# . ==> PUNCT ==> False
# Rubina ==> PROPN ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> True
# the ==> DET ==> True
# Raktbeej ==> NOUN ==> False
# is ==> AUX ==> True
# actually ==> ADV ==> False
# a ==> DET ==> True
# mutated ==> VERB ==> False
# version ==> NOUN ==> False
# of ==> ADP ==> True
# smallpox ==> NOUN ==> False
# ; ==> PUNCT ==> False
# a ==> DET ==> True
# deadly ==> ADJ ==> False
# virus ==> NOUN ==> False
# Jim ==> PROPN ==> False
# forced ==> VERB ==> False
# the ==> DET ==> True
# scientist ==> NOUN ==> False
# he ==> PRON ==> True
# 'd ==> AUX ==> True
# captured ==> VERB ==> False
# to ==> PART ==> True
# create ==> VERB ==> False
# . ==> PUNCT ==> False
# She ==> PRON ==> True
# expresses ==> VERB ==> False
# guilt ==> NOUN ==> False
# about ==> ADP ==> True
# betraying ==> VERB ==> False
# Pathaan ==> PROPN ==> False
# , ==> PUNCT ==> False
# not ==> PART ==> True
# knowing ==> VERB ==> False
# that ==> SCONJ ==> True
# her ==> PRON ==> True
# country ==> NOUN ==> False
# would ==> AUX ==> True
# plan ==> VERB ==> False
# such ==> DET ==> True
# an ==> DET ==> True
# attack ==> NOUN ==> False
# . ==> PUNCT ==> False
# They ==> PRON ==> True
# travel ==> VERB ==> False
# to ==> ADP ==> True
# Jim ==> PROPN ==> False
# 's ==> PART ==> True
# lab ==> NOUN ==> False
# in ==> ADP ==> True
# Siberia ==> PROPN ==> False
# and ==> CCONJ ==> True
# manage ==> VERB ==> False
# to ==> PART ==> True
# recover ==> VERB ==> False
# one ==> NUM ==> True
# orb ==> NOUN ==> False
# containing ==> VERB ==> False
# the ==> DET ==> True
# virus ==> NOUN ==> False
# while ==> SCONJ ==> True
# Jim ==> PROPN ==> False
# escapes ==> VERB ==> False
# with ==> ADP ==> True
# the ==> DET ==> True
# other ==> ADJ ==> True
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# They ==> PRON ==> True
# take ==> VERB ==> True
# the ==> DET ==> True
# orb ==> NOUN ==> False
# to ==> ADP ==> True
# the ==> DET ==> True
# lab ==> NOUN ==> False
# to ==> PART ==> True
# create ==> VERB ==> False
# a ==> DET ==> True
# vaccine ==> NOUN ==> False
# ; ==> PUNCT ==> False
# however ==> ADV ==> True
# , ==> PUNCT ==> False
# Jim ==> PROPN ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> True
# the ==> DET ==> True
# orb ==> NOUN ==> False
# has ==> AUX ==> True
# already ==> ADV ==> True
# spread ==> VERB ==> False
# the ==> DET ==> True
# virus ==> NOUN ==> False
# within ==> ADP ==> True
# the ==> DET ==> True
# lab ==> NOUN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> True
# infected ==> ADJ ==> False
# scientists ==> NOUN ==> False
# , ==> PUNCT ==> False
# along ==> ADP ==> True
# with ==> ADP ==> True
# Nandini ==> PROPN ==> False
# , ==> PUNCT ==> False
# die ==> NOUN ==> False
# , ==> PUNCT ==> False
# and ==> CCONJ ==> True
# the ==> DET ==> True
# lab ==> NOUN ==> False
# is ==> AUX ==> True
# destroyed ==> VERB ==> False
# to ==> PART ==> True
# prevent ==> VERB ==> False
# the ==> DET ==> True
# spread ==> NOUN ==> False
# of ==> ADP ==> True
# the ==> DET ==> True
# virus ==> NOUN ==> False
# . ==> PUNCT ==> False
# Pathaan ==> NOUN ==> False
# learns ==> VERB ==> False
# from ==> ADP ==> True
# Raafe ==> PROPN ==> False
# that ==> SCONJ ==> True
# Jim ==> PROPN ==> False
# 's ==> PART ==> True
# missile ==> NOUN ==> False
# is ==> AUX ==> True
# in ==> ADP ==> True
# Afghanistan ==> PROPN ==> False
# . ==> PUNCT ==> False
# By ==> ADP ==> True
# luring ==> VERB ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> True
# soldiers ==> NOUN ==> False
# into ==> ADP ==> True
# a ==> DET ==> True
# trap ==> NOUN ==> False
# , ==> PUNCT ==> False
# his ==> PRON ==> True
# team ==> NOUN ==> False
# attacks ==> VERB ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> True
# base ==> NOUN ==> False
# . ==> PUNCT ==> False
# Qadir ==> PROPN ==> False
# is ==> AUX ==> True
# killed ==> VERB ==> False
# by ==> ADP ==> True
# Rubina ==> PROPN ==> False
# and ==> CCONJ ==> True
# Pathaan ==> PROPN ==> False
# chases ==> NOUN ==> False
# after ==> ADP ==> True
# Jim ==> PROPN ==> False
# with ==> ADP ==> True
# a ==> DET ==> True
# jetpack ==> NOUN ==> False
# . ==> PUNCT ==> False
# They ==> PRON ==> True
# crash ==> NOUN ==> False
# - ==> PUNCT ==> False
# land ==> NOUN ==> False
# into ==> ADP ==> True
# a ==> DET ==> True
# cabin ==> NOUN ==> False
# atop ==> ADP ==> False
# a ==> DET ==> True
# cliff ==> NOUN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# Rubina ==> PROPN ==> False
# deactivates ==> VERB ==> False
# the ==> DET ==> True
# missile ==> NOUN ==> False
# containing ==> VERB ==> False
# the ==> DET ==> True
# virus ==> NOUN ==> False
# but ==> CCONJ ==> True
# finds ==> VERB ==> False
# that ==> SCONJ ==> True
# Raktbeej ==> NOUN ==> False
# is ==> AUX ==> True
# actually ==> ADV ==> False
# in ==> ADP ==> True
# a ==> DET ==> True
# passenger ==> NOUN ==> False
# - ==> PUNCT ==> False
# bound ==> VERB ==> False
# airplane ==> NOUN ==> False
# about ==> ADP ==> True
# to ==> PART ==> True
# land ==> VERB ==> False
# in ==> ADP ==> True
# Delhi ==> PROPN ==> False
# — ==> PUNCT ==> False
# and ==> CCONJ ==> True
# Jim ==> PROPN ==> False
# has ==> VERB ==> True
# the ==> DET ==> True
# detonator ==> NOUN ==> False
# . ==> PUNCT ==> False
# Luthra ==> PROPN ==> False
# remorsefully ==> ADV ==> False
# orders ==> VERB ==> False
# the ==> DET ==> True
# plane ==> NOUN ==> False
# to ==> PART ==> True
# be ==> AUX ==> True
# blown ==> VERB ==> False
# up ==> ADP ==> True
# to ==> PART ==> True
# prevent ==> VERB ==> False
# the ==> DET ==> True
# virus ==> NOUN ==> False
# ' ==> PART ==> False
# spread ==> NOUN ==> False
# as ==> ADP ==> True
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> True
# Jim ==> PROPN ==> False
# fight ==> NOUN ==> False
# . ==> PUNCT ==> False
# Pathaan ==> NOUN ==> False
# manages ==> VERB ==> False
# to ==> PART ==> True
# deactivate ==> VERB ==> False
# Raktbeej ==> NOUN ==> False
# and ==> CCONJ ==> True
# throw ==> VERB ==> False
# Jim ==> PROPN ==> False
# off ==> ADP ==> True
# the ==> DET ==> True
# cliff ==> NOUN ==> False
# , ==> PUNCT ==> False
# resulting ==> VERB ==> False
# in ==> ADP ==> True
# his ==> PRON ==> True
# apparent ==> ADJ ==> False
# death ==> NOUN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> True
# passenger ==> NOUN ==> False
# plane ==> NOUN ==> False
# lands ==> VERB ==> False
# safely ==> ADV ==> False
# and ==> CCONJ ==> True
# Pathaan ==> PROPN ==> False
# is ==> AUX ==> True
# reinstated ==> VERB ==> False
# into ==> ADP ==> True
# RAW ==> PROPN ==> False
# and ==> CCONJ ==> True
# made ==> VERB ==> True
# head ==> NOUN ==> False
# of ==> ADP ==> True
# JOCR ==> PROPN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# In ==> ADP ==> True
# a ==> DET ==> True
# mid ==> ADJ ==> False
# - ==> NOUN ==> False
# credits ==> NOUN ==> False
# scene ==> NOUN ==> False
# , ==> PUNCT ==> False
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> True
# Tiger ==> PROPN ==> False
# ponder ==> NOUN ==> False
# retiring ==> VERB ==> False
# and ==> CCONJ ==> True
# suggest ==> VERB ==> False
# younger ==> ADJ ==> False
# agents ==> NOUN ==> False
# who ==> PRON ==> True
# can ==> AUX ==> True
# replace ==> VERB ==> False
# them ==> PRON ==> True
# . ==> PUNCT ==> False
# Eventually ==> ADV ==> False
# , ==> PUNCT ==> False
# they ==> PRON ==> True
# decide ==> VERB ==> False
# those ==> DET ==> True
# agents ==> NOUN ==> False
# are ==> AUX ==> True
# n't ==> PART ==> True
# good ==> ADJ ==> False
# enough ==> ADV ==> True
# and ==> CCONJ ==> True
# they ==> PRON ==> True
# 'll ==> AUX ==> True
# have ==> VERB ==> True
# to ==> PART ==> True
# keep ==> VERB ==> True
# fighting ==> VERB ==> False
# the ==> DET ==> True
# threats ==> NOUN ==> False
# themselves ==> PRON ==> True
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False

# %% [markdown]
# ## Not a punctuation

# %%
for token in Doc:
    print(token,'==>',token.pos_,'==>',token.is_punct)
# Out:
# Pathaan ==> PROPN ==> False
# is ==> AUX ==> False
# a ==> DET ==> False
# 2023 ==> NUM ==> False
# Indian ==> PROPN ==> False
# Hindi ==> PROPN ==> False
# - ==> PUNCT ==> True
# language ==> NOUN ==> False
# action ==> NOUN ==> False
# thriller ==> NOUN ==> False
# film ==> NOUN ==> False
# directed ==> VERB ==> False
# by ==> ADP ==> False
# Siddharth ==> PROPN ==> False
# Anand ==> PROPN ==> False
# and ==> CCONJ ==> False
# produced ==> VERB ==> False
# by ==> ADP ==> False
# Aditya ==> PROPN ==> False
# Chopra ==> PROPN ==> False
# of ==> ADP ==> False
# Yash ==> PROPN ==> False
# Raj ==> PROPN ==> False
# Films ==> PROPN ==> False
# . ==> PUNCT ==> True
# The ==> DET ==> False
# fourth ==> ADJ ==> False
# instalment ==> NOUN ==> False
# in ==> ADP ==> False
# the ==> DET ==> False
# YRF ==> PROPN ==> False
# Spy ==> PROPN ==> False
# Universe ==> PROPN ==> False
# , ==> PUNCT ==> True
# it ==> PRON ==> False
# stars ==> VERB ==> False
# Shah ==> PROPN ==> False
# Rukh ==> PROPN ==> False
# Khan ==> PROPN ==> False
# , ==> PUNCT ==> True
# Deepika ==> PROPN ==> False
# Padukone ==> PROPN ==> False
# , ==> PUNCT ==> True
# and ==> CCONJ ==> False
# John ==> PROPN ==> False
# Abraham ==> PROPN ==> False
# , ==> PUNCT ==> True
# alongside ==> ADP ==> False
# Dimple ==> PROPN ==> False
# Kapadia ==> PROPN ==> False
# and ==> CCONJ ==> False
# Ashutosh ==> PROPN ==> False
# Rana ==> PROPN ==> False
# . ==> PUNCT ==> True
# Written ==> VERB ==> False
# by ==> ADP ==> False
# Shridhar ==> PROPN ==> False
# Raghavan ==> PROPN ==> False
# and ==> CCONJ ==> False
# Abbas ==> PROPN ==> False
# Tyrewala ==> PROPN ==> False
# from ==> ADP ==> False
# a ==> DET ==> False
# story ==> NOUN ==> False
# by ==> ADP ==> False
# Anand ==> PROPN ==> False
# , ==> PUNCT ==> True
# the ==> DET ==> False
# film ==> NOUN ==> False
# is ==> AUX ==> False
# about ==> ADP ==> False
# Pathaan ==> PROPN ==> False
# , ==> PUNCT ==> True
# an ==> DET ==> False
# exiled ==> VERB ==> False
# RAW ==> ADJ ==> False
# agent ==> NOUN ==> False
# , ==> PUNCT ==> True
# who ==> PRON ==> False
# must ==> AUX ==> False
# work ==> VERB ==> False
# with ==> ADP ==> False
# ISI ==> PROPN ==> False
# agent ==> NOUN ==> False
# Rubina ==> PROPN ==> False
# to ==> PART ==> False
# take ==> VERB ==> False
# down ==> ADP ==> False
# Jim ==> PROPN ==> False
# , ==> PUNCT ==> True
# a ==> DET ==> False
# former ==> ADJ ==> False
# RAW ==> ADJ ==> False
# agent ==> NOUN ==> False
# - ==> PUNCT ==> True
# turned ==> VERB ==> False
# - ==> PUNCT ==> True
# traitor ==> NOUN ==> False
# , ==> PUNCT ==> True
# who ==> PRON ==> False
# is ==> AUX ==> False
# planning ==> VERB ==> False
# to ==> PART ==> False
# spread ==> VERB ==> False
# a ==> DET ==> False
# deadly ==> ADJ ==> False
# lab ==> NOUN ==> False
# - ==> PUNCT ==> True
# generated ==> VERB ==> False
# virus ==> NOUN ==> False
# across ==> ADP ==> False
# India ==> PROPN ==> False
# . ==> PUNCT ==> True
#
#  ==> SPACE ==> False
# Principal ==> PROPN ==> False
# photography ==> NOUN ==> False
# for ==> ADP ==> False
# Pathaan ==> PROPN ==> False
# began ==> VERB ==> False
# in ==> ADP ==> False
# November ==> PROPN ==> False
# 2020 ==> NUM ==> False
# in ==> ADP ==> False
# Mumbai ==> PROPN ==> False
# . ==> PUNCT ==> True
# The ==> DET ==> False
# film ==> NOUN ==> False
# was ==> AUX ==> False
# shot ==> VERB ==> False
# over ==> ADP ==> False
# various ==> ADJ ==> False
# locations ==> NOUN ==> False
# in ==> ADP ==> False
# India ==> PROPN ==> False
# , ==> PUNCT ==> True
# Afghanistan ==> PROPN ==> False
# , ==> PUNCT ==> True
# Spain ==> PROPN ==> False
# , ==> PUNCT ==> True
# UAE ==> PROPN ==> False
# , ==> PUNCT ==> True
# Turkey ==> PROPN ==> False
# , ==> PUNCT ==> True
# Russia ==> PROPN ==> False
# , ==> PUNCT ==> True
# Italy ==> PROPN ==> False
# and ==> CCONJ ==> False
# France ==> PROPN ==> False
# . ==> PUNCT ==> True
# Two ==> NUM ==> False
# songs ==> NOUN ==> False
# were ==> AUX ==> False
# composed ==> VERB ==> False
# by ==> ADP ==> False
# the ==> DET ==> False
# duo ==> ADJ ==> False
# Vishal ==> PROPN ==> False
# – ==> PUNCT ==> True
# Shekhar ==> PROPN ==> False
# , ==> PUNCT ==> True
# while ==> SCONJ ==> False
# Sanchit ==> PROPN ==> False
# Balhara ==> PROPN ==> False
# and ==> CCONJ ==> False
# Ankit ==> PROPN ==> False
# Balhara ==> PROPN ==> False
# provided ==> VERB ==> False
# the ==> DET ==> False
# score ==> NOUN ==> False
# . ==> PUNCT ==> True
# The ==> DET ==> False
# music ==> NOUN ==> False
# video ==> NOUN ==> False
# of ==> ADP ==> False
# one ==> NUM ==> False
# song ==> NOUN ==> False
# , ==> PUNCT ==> True
# " ==> PUNCT ==> True
# Besharam ==> PROPN ==> False
# Rang ==> PROPN ==> False
# " ==> PUNCT ==> True
# , ==> PUNCT ==> True
# featured ==> VERB ==> False
# Padukone ==> PROPN ==> False
# in ==> ADP ==> False
# a ==> DET ==> False
# saffron ==> NOUN ==> False
# bikini ==> NOUN ==> False
# , ==> PUNCT ==> True
# which ==> PRON ==> False
# led ==> VERB ==> False
# to ==> ADP ==> False
# protests ==> NOUN ==> False
# by ==> ADP ==> False
# right ==> ADJ ==> False
# - ==> PUNCT ==> True
# wing ==> NOUN ==> False
# Hindutva ==> PROPN ==> False
# groups ==> NOUN ==> False
# and ==> CCONJ ==> False
# an ==> DET ==> False
# attempt ==> NOUN ==> False
# to ==> PART ==> False
# boycott ==> VERB ==> False
# the ==> DET ==> False
# film ==> NOUN ==> False
# ; ==> PUNCT ==> True
# however ==> ADV ==> False
# , ==> PUNCT ==> True
# the ==> DET ==> False
# Central ==> PROPN ==> False
# Board ==> PROPN ==> False
# of ==> ADP ==> False
# Film ==> PROPN ==> False
# Certification ==> PROPN ==> False
# cleared ==> VERB ==> False
# the ==> DET ==> False
# film ==> NOUN ==> False
# for ==> ADP ==> False
# exhibition ==> NOUN ==> False
# after ==> SCONJ ==> False
# certain ==> ADJ ==> False
# edits ==> NOUN ==> False
# were ==> AUX ==> False
# made ==> VERB ==> False
# to ==> ADP ==> False
# the ==> DET ==> False
# song ==> NOUN ==> False
# sequence ==> NOUN ==> False
# . ==> PUNCT ==> True
# The ==> DET ==> False
# film ==> NOUN ==> False
# was ==> AUX ==> False
# made ==> VERB ==> False
# on ==> ADP ==> False
# an ==> DET ==> False
# estimated ==> VERB ==> False
# production ==> NOUN ==> False
# budget ==> NOUN ==> False
# of ==> ADP ==> False
# ₹ ==> PROPN ==> False
# 225 ==> NUM ==> False
# crore ==> NOUN ==> False
# ( ==> PUNCT ==> True
# US$ ==> SYM ==> False
# 28 ==> NUM ==> False
# million ==> NUM ==> False
# ) ==> PUNCT ==> True
# with ==> ADP ==> False
# a ==> DET ==> False
# further ==> ADJ ==> False
# ₹ ==> SYM ==> False
# 15 ==> NUM ==> False
# crore ==> NOUN ==> False
# ( ==> PUNCT ==> True
# US$ ==> SYM ==> False
# 1.9 ==> NUM ==> False
# million ==> NUM ==> False
# ) ==> PUNCT ==> True
# spent ==> VERB ==> False
# on ==> ADP ==> False
# print ==> NOUN ==> False
# and ==> CCONJ ==> False
# advertising ==> NOUN ==> False
# . ==> PUNCT ==> True
# Against ==> ADP ==> False
# the ==> DET ==> False
# norm ==> NOUN ==> False
# , ==> PUNCT ==> True
# pre ==> ADJ ==> False
# - ==> ADJ ==> True
# release ==> ADJ ==> False
# publicity ==> NOUN ==> False
# was ==> AUX ==> False
# limited ==> VERB ==> False
# with ==> ADP ==> False
# no ==> DET ==> False
# media ==> NOUN ==> False
# interactions ==> NOUN ==> False
# or ==> CCONJ ==> False
# public ==> ADJ ==> False
# events ==> NOUN ==> False
# . ==> PUNCT ==> True
#
#  ==> SPACE ==> False
# Pathaan ==> PROPN ==> False
# was ==> AUX ==> False
# released ==> VERB ==> False
# in ==> ADP ==> False
# India ==> PROPN ==> False
# on ==> ADP ==> False
# 25 ==> NUM ==> False
# January ==> PROPN ==> False
# 2023 ==> NUM ==> False
# , ==> PUNCT ==> True
# coinciding ==> VERB ==> False
# with ==> ADP ==> False
# the ==> DET ==> False
# Republic ==> PROPN ==> False
# Day ==> PROPN ==> False
# weekend ==> NOUN ==> False
# , ==> PUNCT ==> True
# in ==> ADP ==> False
# IMAX ==> PROPN ==> False
# , ==> PUNCT ==> True
# 4DX ==> NUM ==> False
# and ==> CCONJ ==> False
# standard ==> ADJ ==> False
# formats ==> NOUN ==> False
# along ==> ADP ==> False
# with ==> ADP ==> False
# dubbed ==> VERB ==> False
# versions ==> NOUN ==> False
# in ==> ADP ==> False
# Tamil ==> PROPN ==> False
# and ==> CCONJ ==> False
# Telugu ==> PROPN ==> False
# . ==> PUNCT ==> True
# It ==> PRON ==> False
# received ==> VERB ==> False
# positive ==> ADJ ==> False
# reviews ==> NOUN ==> False
# from ==> ADP ==> False
# critics ==> NOUN ==> False
# and ==> CCONJ ==> False
# broke ==> VERB ==> False
# several ==> ADJ ==> False
# Indian ==> ADJ ==> False
# box ==> NOUN ==> False
# - ==> PUNCT ==> True
# office ==> NOUN ==> False
# records ==> NOUN ==> False
# , ==> PUNCT ==> True
# including ==> VERB ==> False
# the ==> DET ==> False
# biggest ==> ADJ ==> False
# opening ==> NOUN ==> False
# day ==> NOUN ==> False
# and ==> CCONJ ==> False
# opening ==> NOUN ==> False
# weekend ==> NOUN ==> False
# for ==> ADP ==> False
# a ==> DET ==> False
# Hindi ==> PROPN ==> False
# film ==> NOUN ==> False
# . ==> PUNCT ==> True
# Further ==> ADJ ==> False
# opening ==> NOUN ==> False
# records ==> NOUN ==> False
# were ==> AUX ==> False
# set ==> VERB ==> False
# in ==> ADP ==> False
# overseas ==> ADJ ==> False
# markets ==> NOUN ==> False
# . ==> PUNCT ==> True
# Grossing ==> VERB ==> False
# ₹ ==> NOUN ==> False
# 924 ==> NUM ==> False
# crore ==> NOUN ==> False
# ( ==> PUNCT ==> True
# US$ ==> SYM ==> False
# 120 ==> NUM ==> False
# million ==> NUM ==> False
# ) ==> PUNCT ==> True
# worldwide ==> ADV ==> False
# , ==> PUNCT ==> True
# Pathaan ==> PROPN ==> False
# ranks ==> VERB ==> False
# as ==> ADP ==> False
# the ==> DET ==> False
# highest ==> ADV ==> False
# - ==> PUNCT ==> True
# grossing ==> VERB ==> False
# Hindi ==> PROPN ==> False
# film ==> NOUN ==> False
# of ==> ADP ==> False
# 2023 ==> NUM ==> False
# , ==> PUNCT ==> True
# the ==> DET ==> False
# fourth ==> ADV ==> False
# - ==> PUNCT ==> True
# highest ==> ADJ ==> False
# - ==> PUNCT ==> True
# grossing ==> VERB ==> False
# Hindi ==> PROPN ==> False
# film ==> NOUN ==> False
# and ==> CCONJ ==> False
# seventh ==> ADJ ==> False
# - ==> PUNCT ==> True
# highest ==> ADV ==> False
# - ==> PUNCT ==> True
# grossing ==> VERB ==> False
# Indian ==> ADJ ==> False
# film ==> NOUN ==> False
# of ==> ADP ==> False
# all ==> DET ==> False
# time ==> NOUN ==> False
# , ==> PUNCT ==> True
# as ==> ADV ==> False
# well ==> ADV ==> False
# as ==> ADP ==> False
# the ==> DET ==> False
# highest ==> ADV ==> False
# - ==> PUNCT ==> True
# grossing ==> NOUN ==> False
# of ==> ADP ==> False
# Khan ==> PROPN ==> False
# 's ==> PART ==> False
# career ==> NOUN ==> False
# and ==> CCONJ ==> False
# Yash ==> PROPN ==> False
# Raj ==> PROPN ==> False
# Films ==> PROPN ==> False
# ' ==> PART ==> True
# releases ==> NOUN ==> False
# . ==> PUNCT ==> True
#
#  ==> SPACE ==> False
# In ==> ADP ==> False
# 2019 ==> NUM ==> False
# , ==> PUNCT ==> True
# the ==> DET ==> False
# Indian ==> PROPN ==> False
# Government ==> PROPN ==> False
# revokes ==> VERB ==> False
# Article ==> NOUN ==> False
# 370 ==> NUM ==> False
# , ==> PUNCT ==> True
# which ==> PRON ==> False
# grants ==> VERB ==> False
# special ==> ADJ ==> False
# status ==> NOUN ==> False
# for ==> ADP ==> False
# Jammu ==> PROPN ==> False
# and ==> CCONJ ==> False
# Kashmir ==> PROPN ==> False
# . ==> PUNCT ==> True
# The ==> DET ==> False
# news ==> NOUN ==> False
# impacts ==> VERB ==> False
# a ==> DET ==> False
# cancer ==> NOUN ==> False
# - ==> PUNCT ==> True
# ridden ==> VERB ==> False
# Pakistani ==> ADJ ==> False
# army ==> NOUN ==> False
# general ==> NOUN ==> False
# , ==> PUNCT ==> True
# Qadir ==> PROPN ==> False
# , ==> PUNCT ==> True
# who ==> PRON ==> False
# decides ==> VERB ==> False
# to ==> PART ==> False
# exact ==> VERB ==> False
# vengeance ==> NOUN ==> False
# against ==> ADP ==> False
# India ==> PROPN ==> False
# . ==> PUNCT ==> True
# He ==> PRON ==> False
# signs ==> VERB ==> False
# a ==> DET ==> False
# contract ==> NOUN ==> False
# with ==> ADP ==> False
# Jim ==> PROPN ==> False
# , ==> PUNCT ==> True
# who ==> PRON ==> False
# leads ==> VERB ==> False
# " ==> PUNCT ==> True
# Outfit ==> VERB ==> False
# X ==> NOUN ==> False
# " ==> PUNCT ==> True
# , ==> PUNCT ==> True
# a ==> DET ==> False
# private ==> ADJ ==> False
# terrorist ==> ADJ ==> False
# organization ==> NOUN ==> False
# . ==> PUNCT ==> True
# Meanwhile ==> ADV ==> False
# , ==> PUNCT ==> True
# Pathaan ==> PROPN ==> False
# , ==> PUNCT ==> True
# a ==> DET ==> False
# former ==> ADJ ==> False
# RAW ==> ADJ ==> False
# agent ==> NOUN ==> False
# , ==> PUNCT ==> True
# and ==> CCONJ ==> False
# his ==> PRON ==> False
# senior ==> ADJ ==> False
# officer ==> NOUN ==> False
# Nandini ==> PROPN ==> False
# , ==> PUNCT ==> True
# open ==> VERB ==> False
# a ==> DET ==> False
# unit ==> NOUN ==> False
# dubbed ==> VERB ==> False
# " ==> PUNCT ==> True
# Joint ==> ADJ ==> False
# Operation ==> PROPN ==> False
# and ==> CCONJ ==> False
# Covert ==> PROPN ==> False
# Research ==> PROPN ==> False
# " ==> PUNCT ==> True
# ( ==> PUNCT ==> True
# JOCR ==> PROPN ==> False
# ) ==> PUNCT ==> True
# , ==> PUNCT ==> True
# recruiting ==> VERB ==> False
# agents ==> NOUN ==> False
# who ==> PRON ==> False
# were ==> AUX ==> False
# forced ==> VERB ==> False
# to ==> PART ==> False
# retire ==> VERB ==> False
# due ==> ADP ==> False
# to ==> ADP ==> False
# trauma ==> NOUN ==> False
# or ==> CCONJ ==> False
# injury ==> NOUN ==> False
# . ==> PUNCT ==> True
#
#  ==> SPACE ==> False
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> False
# his ==> PRON ==> False
# team ==> NOUN ==> False
# head ==> NOUN ==> False
# to ==> ADP ==> False
# Dubai ==> PROPN ==> False
# to ==> PART ==> False
# stop ==> VERB ==> False
# Outfit ==> VERB ==> False
# X ==> NOUN ==> False
# from ==> ADP ==> False
# kidnapping ==> VERB ==> False
# two ==> NUM ==> False
# scientists ==> NOUN ==> False
# . ==> PUNCT ==> True
# Jim ==> PROPN ==> False
# fights ==> VERB ==> False
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> False
# manages ==> VERB ==> False
# to ==> PART ==> False
# escape ==> VERB ==> False
# with ==> ADP ==> False
# one ==> NUM ==> False
# of ==> ADP ==> False
# the ==> DET ==> False
# scientists ==> NOUN ==> False
# . ==> PUNCT ==> True
# RAW ==> ADJ ==> False
# joint ==> ADJ ==> False
# secretary ==> NOUN ==> False
# Colonel ==> PROPN ==> False
# Sunil ==> PROPN ==> False
# Luthra ==> PROPN ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> False
# Jim ==> PROPN ==> False
# was ==> AUX ==> False
# a ==> DET ==> False
# former ==> ADJ ==> False
# RAW ==> ADJ ==> False
# agent ==> NOUN ==> False
# and ==> CCONJ ==> False
# Kabir ==> PROPN ==> False
# 's ==> PART ==> False
# partner ==> NOUN ==> False
# : ==> PUNCT ==> True
# when ==> SCONJ ==> False
# he ==> PRON ==> False
# and ==> CCONJ ==> False
# his ==> PRON ==> False
# family ==> NOUN ==> False
# were ==> AUX ==> False
# kidnapped ==> VERB ==> False
# by ==> ADP ==> False
# Somalian ==> ADJ ==> False
# terrorists ==> NOUN ==> False
# , ==> PUNCT ==> True
# the ==> DET ==> False
# agency ==> NOUN ==> False
# refused ==> VERB ==> False
# to ==> PART ==> False
# negotiate ==> VERB ==> False
# with ==> ADP ==> False
# them ==> PRON ==> False
# ; ==> PUNCT ==> True
# as ==> ADP ==> False
# a ==> DET ==> False
# result ==> NOUN ==> False
# , ==> PUNCT ==> True
# the ==> DET ==> False
# terrorists ==> NOUN ==> False
# killed ==> VERB ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# wife ==> NOUN ==> False
# and ==> CCONJ ==> False
# unborn ==> ADJ ==> False
# child ==> NOUN ==> False
# . ==> PUNCT ==> True
# Jim ==> PROPN ==> False
# was ==> AUX ==> False
# posthumously ==> ADV ==> False
# awarded ==> VERB ==> False
# the ==> DET ==> False
# Vir ==> PROPN ==> False
# Chakra ==> PROPN ==> False
# for ==> ADP ==> False
# bravery ==> NOUN ==> False
# but ==> CCONJ ==> False
# he ==> PRON ==> False
# faked ==> VERB ==> False
# his ==> PRON ==> False
# death ==> NOUN ==> False
# and ==> CCONJ ==> False
# now ==> ADV ==> False
# seeks ==> VERB ==> False
# vengeance ==> NOUN ==> False
# against ==> ADP ==> False
# the ==> DET ==> False
# country ==> NOUN ==> False
# for ==> ADP ==> False
# abandoning ==> VERB ==> False
# him ==> PRON ==> False
# and ==> CCONJ ==> False
# his ==> PRON ==> False
# family ==> NOUN ==> False
# . ==> PUNCT ==> True
#
#  ==> SPACE ==> False
# Pathaan ==> PROPN ==> False
# also ==> ADV ==> False
# learns ==> VERB ==> False
# of ==> ADP ==> False
# something ==> PRON ==> False
# called ==> VERB ==> False
# " ==> PUNCT ==> True
# Raktbeej ==> NOUN ==> False
# " ==> PUNCT ==> True
# and ==> CCONJ ==> False
# about ==> ADP ==> False
# Rubina ==> PROPN ==> False
# Mohsin ==> PROPN ==> False
# , ==> PUNCT ==> True
# a ==> DET ==> False
# Pakistani ==> ADJ ==> False
# doctor ==> NOUN ==> False
# in ==> ADP ==> False
# Spain ==> PROPN ==> False
# who ==> PRON ==> False
# works ==> VERB ==> False
# with ==> ADP ==> False
# Jim ==> PROPN ==> False
# . ==> PUNCT ==> True
# He ==> PRON ==> False
# travels ==> VERB ==> False
# to ==> ADP ==> False
# Spain ==> PROPN ==> False
# and ==> CCONJ ==> False
# is ==> AUX ==> False
# captured ==> VERB ==> False
# by ==> ADP ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# men ==> NOUN ==> False
# , ==> PUNCT ==> True
# where ==> SCONJ ==> False
# he ==> PRON ==> False
# learns ==> VERB ==> False
# that ==> SCONJ ==> False
# Rubina ==> PROPN ==> False
# is ==> AUX ==> False
# an ==> DET ==> False
# ex ==> ADJ ==> False
# - ==> ADJ ==> True
# ISI ==> ADJ ==> False
# agent ==> NOUN ==> False
# . ==> PUNCT ==> True
# Rubina ==> PROPN ==> False
# saves ==> VERB ==> False
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> False
# Raktbeej ==> NOUN ==> False
# is ==> AUX ==> False
# in ==> ADP ==> False
# Moscow ==> PROPN ==> False
# . ==> PUNCT ==> True
# They ==> PRON ==> False
# travel ==> VERB ==> False
# there ==> ADV ==> False
# to ==> PART ==> False
# steal ==> VERB ==> False
# it ==> PRON ==> False
# before ==> SCONJ ==> False
# Jim ==> PROPN ==> False
# does ==> VERB ==> False
# . ==> PUNCT ==> True
# Rubina ==> PROPN ==> False
# betrays ==> VERB ==> False
# Pathaan ==> PROPN ==> False
# , ==> PUNCT ==> True
# leaving ==> VERB ==> False
# him ==> PRON ==> False
# to ==> PART ==> False
# captured ==> VERB ==> False
# by ==> ADP ==> False
# the ==> DET ==> False
# Russian ==> ADJ ==> False
# police ==> NOUN ==> False
# . ==> PUNCT ==> True
# She ==> PRON ==> False
# had ==> AUX ==> False
# been ==> AUX ==> False
# working ==> VERB ==> False
# for ==> ADP ==> False
# Jim ==> PROPN ==> False
# all ==> ADV ==> False
# along ==> ADV ==> False
# . ==> PUNCT ==> True
# Pathaan ==> PROPN ==> False
# is ==> AUX ==> False
# taken ==> VERB ==> False
# to ==> ADP ==> False
# prison ==> NOUN ==> False
# by ==> ADP ==> False
# train ==> NOUN ==> False
# , ==> PUNCT ==> True
# where ==> SCONJ ==> False
# he ==> PRON ==> False
# is ==> AUX ==> False
# nearly ==> ADV ==> False
# murdered ==> VERB ==> False
# ; ==> PUNCT ==> True
# he ==> PRON ==> False
# is ==> AUX ==> False
# saved ==> VERB ==> False
# by ==> ADP ==> False
# fellow ==> ADJ ==> False
# agent ==> NOUN ==> False
# Tiger ==> PROPN ==> False
# . ==> PUNCT ==> True
#
#  ==> SPACE ==> False
# Three ==> NUM ==> False
# years ==> NOUN ==> False
# later ==> ADV ==> False
# , ==> PUNCT ==> True
# during ==> ADP ==> False
# which ==> PRON ==> False
# Pathaan ==> PROPN ==> False
# was ==> AUX ==> False
# in ==> ADP ==> False
# hiding ==> NOUN ==> False
# , ==> PUNCT ==> True
# he ==> PRON ==> False
# captures ==> VERB ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# henchman ==> NOUN ==> False
# , ==> PUNCT ==> True
# Raafe ==> PROPN ==> False
# . ==> PUNCT ==> True
# Nandini ==> PROPN ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> False
# Rubina ==> PROPN ==> False
# was ==> AUX ==> False
# captured ==> VERB ==> False
# on ==> ADP ==> False
# CCTV ==> PROPN ==> False
# footage ==> NOUN ==> False
# in ==> ADP ==> False
# Paris ==> PROPN ==> False
# . ==> PUNCT ==> True
# Pathaan ==> PROPN ==> False
# realizes ==> VERB ==> False
# Rubina ==> PROPN ==> False
# wants ==> VERB ==> False
# him ==> PRON ==> False
# to ==> PART ==> False
# meet ==> VERB ==> False
# her ==> PRON ==> False
# there ==> ADV ==> False
# , ==> PUNCT ==> True
# and ==> CCONJ ==> False
# does ==> VERB ==> False
# so ==> ADV ==> False
# . ==> PUNCT ==> True
# Rubina ==> PROPN ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> False
# the ==> DET ==> False
# Raktbeej ==> NOUN ==> False
# is ==> AUX ==> False
# actually ==> ADV ==> False
# a ==> DET ==> False
# mutated ==> VERB ==> False
# version ==> NOUN ==> False
# of ==> ADP ==> False
# smallpox ==> NOUN ==> False
# ; ==> PUNCT ==> True
# a ==> DET ==> False
# deadly ==> ADJ ==> False
# virus ==> NOUN ==> False
# Jim ==> PROPN ==> False
# forced ==> VERB ==> False
# the ==> DET ==> False
# scientist ==> NOUN ==> False
# he ==> PRON ==> False
# 'd ==> AUX ==> False
# captured ==> VERB ==> False
# to ==> PART ==> False
# create ==> VERB ==> False
# . ==> PUNCT ==> True
# She ==> PRON ==> False
# expresses ==> VERB ==> False
# guilt ==> NOUN ==> False
# about ==> ADP ==> False
# betraying ==> VERB ==> False
# Pathaan ==> PROPN ==> False
# , ==> PUNCT ==> True
# not ==> PART ==> False
# knowing ==> VERB ==> False
# that ==> SCONJ ==> False
# her ==> PRON ==> False
# country ==> NOUN ==> False
# would ==> AUX ==> False
# plan ==> VERB ==> False
# such ==> DET ==> False
# an ==> DET ==> False
# attack ==> NOUN ==> False
# . ==> PUNCT ==> True
# They ==> PRON ==> False
# travel ==> VERB ==> False
# to ==> ADP ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# lab ==> NOUN ==> False
# in ==> ADP ==> False
# Siberia ==> PROPN ==> False
# and ==> CCONJ ==> False
# manage ==> VERB ==> False
# to ==> PART ==> False
# recover ==> VERB ==> False
# one ==> NUM ==> False
# orb ==> NOUN ==> False
# containing ==> VERB ==> False
# the ==> DET ==> False
# virus ==> NOUN ==> False
# while ==> SCONJ ==> False
# Jim ==> PROPN ==> False
# escapes ==> VERB ==> False
# with ==> ADP ==> False
# the ==> DET ==> False
# other ==> ADJ ==> False
# . ==> PUNCT ==> True
#
#  ==> SPACE ==> False
# They ==> PRON ==> False
# take ==> VERB ==> False
# the ==> DET ==> False
# orb ==> NOUN ==> False
# to ==> ADP ==> False
# the ==> DET ==> False
# lab ==> NOUN ==> False
# to ==> PART ==> False
# create ==> VERB ==> False
# a ==> DET ==> False
# vaccine ==> NOUN ==> False
# ; ==> PUNCT ==> True
# however ==> ADV ==> False
# , ==> PUNCT ==> True
# Jim ==> PROPN ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> False
# the ==> DET ==> False
# orb ==> NOUN ==> False
# has ==> AUX ==> False
# already ==> ADV ==> False
# spread ==> VERB ==> False
# the ==> DET ==> False
# virus ==> NOUN ==> False
# within ==> ADP ==> False
# the ==> DET ==> False
# lab ==> NOUN ==> False
# . ==> PUNCT ==> True
# The ==> DET ==> False
# infected ==> ADJ ==> False
# scientists ==> NOUN ==> False
# , ==> PUNCT ==> True
# along ==> ADP ==> False
# with ==> ADP ==> False
# Nandini ==> PROPN ==> False
# , ==> PUNCT ==> True
# die ==> NOUN ==> False
# , ==> PUNCT ==> True
# and ==> CCONJ ==> False
# the ==> DET ==> False
# lab ==> NOUN ==> False
# is ==> AUX ==> False
# destroyed ==> VERB ==> False
# to ==> PART ==> False
# prevent ==> VERB ==> False
# the ==> DET ==> False
# spread ==> NOUN ==> False
# of ==> ADP ==> False
# the ==> DET ==> False
# virus ==> NOUN ==> False
# . ==> PUNCT ==> True
# Pathaan ==> NOUN ==> False
# learns ==> VERB ==> False
# from ==> ADP ==> False
# Raafe ==> PROPN ==> False
# that ==> SCONJ ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# missile ==> NOUN ==> False
# is ==> AUX ==> False
# in ==> ADP ==> False
# Afghanistan ==> PROPN ==> False
# . ==> PUNCT ==> True
# By ==> ADP ==> False
# luring ==> VERB ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# soldiers ==> NOUN ==> False
# into ==> ADP ==> False
# a ==> DET ==> False
# trap ==> NOUN ==> False
# , ==> PUNCT ==> True
# his ==> PRON ==> False
# team ==> NOUN ==> False
# attacks ==> VERB ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# base ==> NOUN ==> False
# . ==> PUNCT ==> True
# Qadir ==> PROPN ==> False
# is ==> AUX ==> False
# killed ==> VERB ==> False
# by ==> ADP ==> False
# Rubina ==> PROPN ==> False
# and ==> CCONJ ==> False
# Pathaan ==> PROPN ==> False
# chases ==> NOUN ==> False
# after ==> ADP ==> False
# Jim ==> PROPN ==> False
# with ==> ADP ==> False
# a ==> DET ==> False
# jetpack ==> NOUN ==> False
# . ==> PUNCT ==> True
# They ==> PRON ==> False
# crash ==> NOUN ==> False
# - ==> PUNCT ==> True
# land ==> NOUN ==> False
# into ==> ADP ==> False
# a ==> DET ==> False
# cabin ==> NOUN ==> False
# atop ==> ADP ==> False
# a ==> DET ==> False
# cliff ==> NOUN ==> False
# . ==> PUNCT ==> True
#
#  ==> SPACE ==> False
# Rubina ==> PROPN ==> False
# deactivates ==> VERB ==> False
# the ==> DET ==> False
# missile ==> NOUN ==> False
# containing ==> VERB ==> False
# the ==> DET ==> False
# virus ==> NOUN ==> False
# but ==> CCONJ ==> False
# finds ==> VERB ==> False
# that ==> SCONJ ==> False
# Raktbeej ==> NOUN ==> False
# is ==> AUX ==> False
# actually ==> ADV ==> False
# in ==> ADP ==> False
# a ==> DET ==> False
# passenger ==> NOUN ==> False
# - ==> PUNCT ==> True
# bound ==> VERB ==> False
# airplane ==> NOUN ==> False
# about ==> ADP ==> False
# to ==> PART ==> False
# land ==> VERB ==> False
# in ==> ADP ==> False
# Delhi ==> PROPN ==> False
# — ==> PUNCT ==> True
# and ==> CCONJ ==> False
# Jim ==> PROPN ==> False
# has ==> VERB ==> False
# the ==> DET ==> False
# detonator ==> NOUN ==> False
# . ==> PUNCT ==> True
# Luthra ==> PROPN ==> False
# remorsefully ==> ADV ==> False
# orders ==> VERB ==> False
# the ==> DET ==> False
# plane ==> NOUN ==> False
# to ==> PART ==> False
# be ==> AUX ==> False
# blown ==> VERB ==> False
# up ==> ADP ==> False
# to ==> PART ==> False
# prevent ==> VERB ==> False
# the ==> DET ==> False
# virus ==> NOUN ==> False
# ' ==> PART ==> True
# spread ==> NOUN ==> False
# as ==> ADP ==> False
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> False
# Jim ==> PROPN ==> False
# fight ==> NOUN ==> False
# . ==> PUNCT ==> True
# Pathaan ==> NOUN ==> False
# manages ==> VERB ==> False
# to ==> PART ==> False
# deactivate ==> VERB ==> False
# Raktbeej ==> NOUN ==> False
# and ==> CCONJ ==> False
# throw ==> VERB ==> False
# Jim ==> PROPN ==> False
# off ==> ADP ==> False
# the ==> DET ==> False
# cliff ==> NOUN ==> False
# , ==> PUNCT ==> True
# resulting ==> VERB ==> False
# in ==> ADP ==> False
# his ==> PRON ==> False
# apparent ==> ADJ ==> False
# death ==> NOUN ==> False
# . ==> PUNCT ==> True
# The ==> DET ==> False
# passenger ==> NOUN ==> False
# plane ==> NOUN ==> False
# lands ==> VERB ==> False
# safely ==> ADV ==> False
# and ==> CCONJ ==> False
# Pathaan ==> PROPN ==> False
# is ==> AUX ==> False
# reinstated ==> VERB ==> False
# into ==> ADP ==> False
# RAW ==> PROPN ==> False
# and ==> CCONJ ==> False
# made ==> VERB ==> False
# head ==> NOUN ==> False
# of ==> ADP ==> False
# JOCR ==> PROPN ==> False
# . ==> PUNCT ==> True
#
#  ==> SPACE ==> False
# In ==> ADP ==> False
# a ==> DET ==> False
# mid ==> ADJ ==> False
# - ==> NOUN ==> True
# credits ==> NOUN ==> False
# scene ==> NOUN ==> False
# , ==> PUNCT ==> True
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> False
# Tiger ==> PROPN ==> False
# ponder ==> NOUN ==> False
# retiring ==> VERB ==> False
# and ==> CCONJ ==> False
# suggest ==> VERB ==> False
# younger ==> ADJ ==> False
# agents ==> NOUN ==> False
# who ==> PRON ==> False
# can ==> AUX ==> False
# replace ==> VERB ==> False
# them ==> PRON ==> False
# . ==> PUNCT ==> True
# Eventually ==> ADV ==> False
# , ==> PUNCT ==> True
# they ==> PRON ==> False
# decide ==> VERB ==> False
# those ==> DET ==> False
# agents ==> NOUN ==> False
# are ==> AUX ==> False
# n't ==> PART ==> False
# good ==> ADJ ==> False
# enough ==> ADV ==> False
# and ==> CCONJ ==> False
# they ==> PRON ==> False
# 'll ==> AUX ==> False
# have ==> VERB ==> False
# to ==> PART ==> False
# keep ==> VERB ==> False
# fighting ==> VERB ==> False
# the ==> DET ==> False
# threats ==> NOUN ==> False
# themselves ==> PRON ==> False
# . ==> PUNCT ==> True
#
#  ==> SPACE ==> False

# %% [markdown]
# ## Not a Number

# %%
for token in Doc:
    print(token,'==>',token.pos_,'==>',token.is_digit)
# Out:
# Pathaan ==> PROPN ==> False
# is ==> AUX ==> False
# a ==> DET ==> False
# 2023 ==> NUM ==> True
# Indian ==> PROPN ==> False
# Hindi ==> PROPN ==> False
# - ==> PUNCT ==> False
# language ==> NOUN ==> False
# action ==> NOUN ==> False
# thriller ==> NOUN ==> False
# film ==> NOUN ==> False
# directed ==> VERB ==> False
# by ==> ADP ==> False
# Siddharth ==> PROPN ==> False
# Anand ==> PROPN ==> False
# and ==> CCONJ ==> False
# produced ==> VERB ==> False
# by ==> ADP ==> False
# Aditya ==> PROPN ==> False
# Chopra ==> PROPN ==> False
# of ==> ADP ==> False
# Yash ==> PROPN ==> False
# Raj ==> PROPN ==> False
# Films ==> PROPN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> False
# fourth ==> ADJ ==> False
# instalment ==> NOUN ==> False
# in ==> ADP ==> False
# the ==> DET ==> False
# YRF ==> PROPN ==> False
# Spy ==> PROPN ==> False
# Universe ==> PROPN ==> False
# , ==> PUNCT ==> False
# it ==> PRON ==> False
# stars ==> VERB ==> False
# Shah ==> PROPN ==> False
# Rukh ==> PROPN ==> False
# Khan ==> PROPN ==> False
# , ==> PUNCT ==> False
# Deepika ==> PROPN ==> False
# Padukone ==> PROPN ==> False
# , ==> PUNCT ==> False
# and ==> CCONJ ==> False
# John ==> PROPN ==> False
# Abraham ==> PROPN ==> False
# , ==> PUNCT ==> False
# alongside ==> ADP ==> False
# Dimple ==> PROPN ==> False
# Kapadia ==> PROPN ==> False
# and ==> CCONJ ==> False
# Ashutosh ==> PROPN ==> False
# Rana ==> PROPN ==> False
# . ==> PUNCT ==> False
# Written ==> VERB ==> False
# by ==> ADP ==> False
# Shridhar ==> PROPN ==> False
# Raghavan ==> PROPN ==> False
# and ==> CCONJ ==> False
# Abbas ==> PROPN ==> False
# Tyrewala ==> PROPN ==> False
# from ==> ADP ==> False
# a ==> DET ==> False
# story ==> NOUN ==> False
# by ==> ADP ==> False
# Anand ==> PROPN ==> False
# , ==> PUNCT ==> False
# the ==> DET ==> False
# film ==> NOUN ==> False
# is ==> AUX ==> False
# about ==> ADP ==> False
# Pathaan ==> PROPN ==> False
# , ==> PUNCT ==> False
# an ==> DET ==> False
# exiled ==> VERB ==> False
# RAW ==> ADJ ==> False
# agent ==> NOUN ==> False
# , ==> PUNCT ==> False
# who ==> PRON ==> False
# must ==> AUX ==> False
# work ==> VERB ==> False
# with ==> ADP ==> False
# ISI ==> PROPN ==> False
# agent ==> NOUN ==> False
# Rubina ==> PROPN ==> False
# to ==> PART ==> False
# take ==> VERB ==> False
# down ==> ADP ==> False
# Jim ==> PROPN ==> False
# , ==> PUNCT ==> False
# a ==> DET ==> False
# former ==> ADJ ==> False
# RAW ==> ADJ ==> False
# agent ==> NOUN ==> False
# - ==> PUNCT ==> False
# turned ==> VERB ==> False
# - ==> PUNCT ==> False
# traitor ==> NOUN ==> False
# , ==> PUNCT ==> False
# who ==> PRON ==> False
# is ==> AUX ==> False
# planning ==> VERB ==> False
# to ==> PART ==> False
# spread ==> VERB ==> False
# a ==> DET ==> False
# deadly ==> ADJ ==> False
# lab ==> NOUN ==> False
# - ==> PUNCT ==> False
# generated ==> VERB ==> False
# virus ==> NOUN ==> False
# across ==> ADP ==> False
# India ==> PROPN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# Principal ==> PROPN ==> False
# photography ==> NOUN ==> False
# for ==> ADP ==> False
# Pathaan ==> PROPN ==> False
# began ==> VERB ==> False
# in ==> ADP ==> False
# November ==> PROPN ==> False
# 2020 ==> NUM ==> True
# in ==> ADP ==> False
# Mumbai ==> PROPN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> False
# film ==> NOUN ==> False
# was ==> AUX ==> False
# shot ==> VERB ==> False
# over ==> ADP ==> False
# various ==> ADJ ==> False
# locations ==> NOUN ==> False
# in ==> ADP ==> False
# India ==> PROPN ==> False
# , ==> PUNCT ==> False
# Afghanistan ==> PROPN ==> False
# , ==> PUNCT ==> False
# Spain ==> PROPN ==> False
# , ==> PUNCT ==> False
# UAE ==> PROPN ==> False
# , ==> PUNCT ==> False
# Turkey ==> PROPN ==> False
# , ==> PUNCT ==> False
# Russia ==> PROPN ==> False
# , ==> PUNCT ==> False
# Italy ==> PROPN ==> False
# and ==> CCONJ ==> False
# France ==> PROPN ==> False
# . ==> PUNCT ==> False
# Two ==> NUM ==> False
# songs ==> NOUN ==> False
# were ==> AUX ==> False
# composed ==> VERB ==> False
# by ==> ADP ==> False
# the ==> DET ==> False
# duo ==> ADJ ==> False
# Vishal ==> PROPN ==> False
# – ==> PUNCT ==> False
# Shekhar ==> PROPN ==> False
# , ==> PUNCT ==> False
# while ==> SCONJ ==> False
# Sanchit ==> PROPN ==> False
# Balhara ==> PROPN ==> False
# and ==> CCONJ ==> False
# Ankit ==> PROPN ==> False
# Balhara ==> PROPN ==> False
# provided ==> VERB ==> False
# the ==> DET ==> False
# score ==> NOUN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> False
# music ==> NOUN ==> False
# video ==> NOUN ==> False
# of ==> ADP ==> False
# one ==> NUM ==> False
# song ==> NOUN ==> False
# , ==> PUNCT ==> False
# " ==> PUNCT ==> False
# Besharam ==> PROPN ==> False
# Rang ==> PROPN ==> False
# " ==> PUNCT ==> False
# , ==> PUNCT ==> False
# featured ==> VERB ==> False
# Padukone ==> PROPN ==> False
# in ==> ADP ==> False
# a ==> DET ==> False
# saffron ==> NOUN ==> False
# bikini ==> NOUN ==> False
# , ==> PUNCT ==> False
# which ==> PRON ==> False
# led ==> VERB ==> False
# to ==> ADP ==> False
# protests ==> NOUN ==> False
# by ==> ADP ==> False
# right ==> ADJ ==> False
# - ==> PUNCT ==> False
# wing ==> NOUN ==> False
# Hindutva ==> PROPN ==> False
# groups ==> NOUN ==> False
# and ==> CCONJ ==> False
# an ==> DET ==> False
# attempt ==> NOUN ==> False
# to ==> PART ==> False
# boycott ==> VERB ==> False
# the ==> DET ==> False
# film ==> NOUN ==> False
# ; ==> PUNCT ==> False
# however ==> ADV ==> False
# , ==> PUNCT ==> False
# the ==> DET ==> False
# Central ==> PROPN ==> False
# Board ==> PROPN ==> False
# of ==> ADP ==> False
# Film ==> PROPN ==> False
# Certification ==> PROPN ==> False
# cleared ==> VERB ==> False
# the ==> DET ==> False
# film ==> NOUN ==> False
# for ==> ADP ==> False
# exhibition ==> NOUN ==> False
# after ==> SCONJ ==> False
# certain ==> ADJ ==> False
# edits ==> NOUN ==> False
# were ==> AUX ==> False
# made ==> VERB ==> False
# to ==> ADP ==> False
# the ==> DET ==> False
# song ==> NOUN ==> False
# sequence ==> NOUN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> False
# film ==> NOUN ==> False
# was ==> AUX ==> False
# made ==> VERB ==> False
# on ==> ADP ==> False
# an ==> DET ==> False
# estimated ==> VERB ==> False
# production ==> NOUN ==> False
# budget ==> NOUN ==> False
# of ==> ADP ==> False
# ₹ ==> PROPN ==> False
# 225 ==> NUM ==> True
# crore ==> NOUN ==> False
# ( ==> PUNCT ==> False
# US$ ==> SYM ==> False
# 28 ==> NUM ==> True
# million ==> NUM ==> False
# ) ==> PUNCT ==> False
# with ==> ADP ==> False
# a ==> DET ==> False
# further ==> ADJ ==> False
# ₹ ==> SYM ==> False
# 15 ==> NUM ==> True
# crore ==> NOUN ==> False
# ( ==> PUNCT ==> False
# US$ ==> SYM ==> False
# 1.9 ==> NUM ==> False
# million ==> NUM ==> False
# ) ==> PUNCT ==> False
# spent ==> VERB ==> False
# on ==> ADP ==> False
# print ==> NOUN ==> False
# and ==> CCONJ ==> False
# advertising ==> NOUN ==> False
# . ==> PUNCT ==> False
# Against ==> ADP ==> False
# the ==> DET ==> False
# norm ==> NOUN ==> False
# , ==> PUNCT ==> False
# pre ==> ADJ ==> False
# - ==> ADJ ==> False
# release ==> ADJ ==> False
# publicity ==> NOUN ==> False
# was ==> AUX ==> False
# limited ==> VERB ==> False
# with ==> ADP ==> False
# no ==> DET ==> False
# media ==> NOUN ==> False
# interactions ==> NOUN ==> False
# or ==> CCONJ ==> False
# public ==> ADJ ==> False
# events ==> NOUN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# Pathaan ==> PROPN ==> False
# was ==> AUX ==> False
# released ==> VERB ==> False
# in ==> ADP ==> False
# India ==> PROPN ==> False
# on ==> ADP ==> False
# 25 ==> NUM ==> True
# January ==> PROPN ==> False
# 2023 ==> NUM ==> True
# , ==> PUNCT ==> False
# coinciding ==> VERB ==> False
# with ==> ADP ==> False
# the ==> DET ==> False
# Republic ==> PROPN ==> False
# Day ==> PROPN ==> False
# weekend ==> NOUN ==> False
# , ==> PUNCT ==> False
# in ==> ADP ==> False
# IMAX ==> PROPN ==> False
# , ==> PUNCT ==> False
# 4DX ==> NUM ==> False
# and ==> CCONJ ==> False
# standard ==> ADJ ==> False
# formats ==> NOUN ==> False
# along ==> ADP ==> False
# with ==> ADP ==> False
# dubbed ==> VERB ==> False
# versions ==> NOUN ==> False
# in ==> ADP ==> False
# Tamil ==> PROPN ==> False
# and ==> CCONJ ==> False
# Telugu ==> PROPN ==> False
# . ==> PUNCT ==> False
# It ==> PRON ==> False
# received ==> VERB ==> False
# positive ==> ADJ ==> False
# reviews ==> NOUN ==> False
# from ==> ADP ==> False
# critics ==> NOUN ==> False
# and ==> CCONJ ==> False
# broke ==> VERB ==> False
# several ==> ADJ ==> False
# Indian ==> ADJ ==> False
# box ==> NOUN ==> False
# - ==> PUNCT ==> False
# office ==> NOUN ==> False
# records ==> NOUN ==> False
# , ==> PUNCT ==> False
# including ==> VERB ==> False
# the ==> DET ==> False
# biggest ==> ADJ ==> False
# opening ==> NOUN ==> False
# day ==> NOUN ==> False
# and ==> CCONJ ==> False
# opening ==> NOUN ==> False
# weekend ==> NOUN ==> False
# for ==> ADP ==> False
# a ==> DET ==> False
# Hindi ==> PROPN ==> False
# film ==> NOUN ==> False
# . ==> PUNCT ==> False
# Further ==> ADJ ==> False
# opening ==> NOUN ==> False
# records ==> NOUN ==> False
# were ==> AUX ==> False
# set ==> VERB ==> False
# in ==> ADP ==> False
# overseas ==> ADJ ==> False
# markets ==> NOUN ==> False
# . ==> PUNCT ==> False
# Grossing ==> VERB ==> False
# ₹ ==> NOUN ==> False
# 924 ==> NUM ==> True
# crore ==> NOUN ==> False
# ( ==> PUNCT ==> False
# US$ ==> SYM ==> False
# 120 ==> NUM ==> True
# million ==> NUM ==> False
# ) ==> PUNCT ==> False
# worldwide ==> ADV ==> False
# , ==> PUNCT ==> False
# Pathaan ==> PROPN ==> False
# ranks ==> VERB ==> False
# as ==> ADP ==> False
# the ==> DET ==> False
# highest ==> ADV ==> False
# - ==> PUNCT ==> False
# grossing ==> VERB ==> False
# Hindi ==> PROPN ==> False
# film ==> NOUN ==> False
# of ==> ADP ==> False
# 2023 ==> NUM ==> True
# , ==> PUNCT ==> False
# the ==> DET ==> False
# fourth ==> ADV ==> False
# - ==> PUNCT ==> False
# highest ==> ADJ ==> False
# - ==> PUNCT ==> False
# grossing ==> VERB ==> False
# Hindi ==> PROPN ==> False
# film ==> NOUN ==> False
# and ==> CCONJ ==> False
# seventh ==> ADJ ==> False
# - ==> PUNCT ==> False
# highest ==> ADV ==> False
# - ==> PUNCT ==> False
# grossing ==> VERB ==> False
# Indian ==> ADJ ==> False
# film ==> NOUN ==> False
# of ==> ADP ==> False
# all ==> DET ==> False
# time ==> NOUN ==> False
# , ==> PUNCT ==> False
# as ==> ADV ==> False
# well ==> ADV ==> False
# as ==> ADP ==> False
# the ==> DET ==> False
# highest ==> ADV ==> False
# - ==> PUNCT ==> False
# grossing ==> NOUN ==> False
# of ==> ADP ==> False
# Khan ==> PROPN ==> False
# 's ==> PART ==> False
# career ==> NOUN ==> False
# and ==> CCONJ ==> False
# Yash ==> PROPN ==> False
# Raj ==> PROPN ==> False
# Films ==> PROPN ==> False
# ' ==> PART ==> False
# releases ==> NOUN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# In ==> ADP ==> False
# 2019 ==> NUM ==> True
# , ==> PUNCT ==> False
# the ==> DET ==> False
# Indian ==> PROPN ==> False
# Government ==> PROPN ==> False
# revokes ==> VERB ==> False
# Article ==> NOUN ==> False
# 370 ==> NUM ==> True
# , ==> PUNCT ==> False
# which ==> PRON ==> False
# grants ==> VERB ==> False
# special ==> ADJ ==> False
# status ==> NOUN ==> False
# for ==> ADP ==> False
# Jammu ==> PROPN ==> False
# and ==> CCONJ ==> False
# Kashmir ==> PROPN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> False
# news ==> NOUN ==> False
# impacts ==> VERB ==> False
# a ==> DET ==> False
# cancer ==> NOUN ==> False
# - ==> PUNCT ==> False
# ridden ==> VERB ==> False
# Pakistani ==> ADJ ==> False
# army ==> NOUN ==> False
# general ==> NOUN ==> False
# , ==> PUNCT ==> False
# Qadir ==> PROPN ==> False
# , ==> PUNCT ==> False
# who ==> PRON ==> False
# decides ==> VERB ==> False
# to ==> PART ==> False
# exact ==> VERB ==> False
# vengeance ==> NOUN ==> False
# against ==> ADP ==> False
# India ==> PROPN ==> False
# . ==> PUNCT ==> False
# He ==> PRON ==> False
# signs ==> VERB ==> False
# a ==> DET ==> False
# contract ==> NOUN ==> False
# with ==> ADP ==> False
# Jim ==> PROPN ==> False
# , ==> PUNCT ==> False
# who ==> PRON ==> False
# leads ==> VERB ==> False
# " ==> PUNCT ==> False
# Outfit ==> VERB ==> False
# X ==> NOUN ==> False
# " ==> PUNCT ==> False
# , ==> PUNCT ==> False
# a ==> DET ==> False
# private ==> ADJ ==> False
# terrorist ==> ADJ ==> False
# organization ==> NOUN ==> False
# . ==> PUNCT ==> False
# Meanwhile ==> ADV ==> False
# , ==> PUNCT ==> False
# Pathaan ==> PROPN ==> False
# , ==> PUNCT ==> False
# a ==> DET ==> False
# former ==> ADJ ==> False
# RAW ==> ADJ ==> False
# agent ==> NOUN ==> False
# , ==> PUNCT ==> False
# and ==> CCONJ ==> False
# his ==> PRON ==> False
# senior ==> ADJ ==> False
# officer ==> NOUN ==> False
# Nandini ==> PROPN ==> False
# , ==> PUNCT ==> False
# open ==> VERB ==> False
# a ==> DET ==> False
# unit ==> NOUN ==> False
# dubbed ==> VERB ==> False
# " ==> PUNCT ==> False
# Joint ==> ADJ ==> False
# Operation ==> PROPN ==> False
# and ==> CCONJ ==> False
# Covert ==> PROPN ==> False
# Research ==> PROPN ==> False
# " ==> PUNCT ==> False
# ( ==> PUNCT ==> False
# JOCR ==> PROPN ==> False
# ) ==> PUNCT ==> False
# , ==> PUNCT ==> False
# recruiting ==> VERB ==> False
# agents ==> NOUN ==> False
# who ==> PRON ==> False
# were ==> AUX ==> False
# forced ==> VERB ==> False
# to ==> PART ==> False
# retire ==> VERB ==> False
# due ==> ADP ==> False
# to ==> ADP ==> False
# trauma ==> NOUN ==> False
# or ==> CCONJ ==> False
# injury ==> NOUN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> False
# his ==> PRON ==> False
# team ==> NOUN ==> False
# head ==> NOUN ==> False
# to ==> ADP ==> False
# Dubai ==> PROPN ==> False
# to ==> PART ==> False
# stop ==> VERB ==> False
# Outfit ==> VERB ==> False
# X ==> NOUN ==> False
# from ==> ADP ==> False
# kidnapping ==> VERB ==> False
# two ==> NUM ==> False
# scientists ==> NOUN ==> False
# . ==> PUNCT ==> False
# Jim ==> PROPN ==> False
# fights ==> VERB ==> False
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> False
# manages ==> VERB ==> False
# to ==> PART ==> False
# escape ==> VERB ==> False
# with ==> ADP ==> False
# one ==> NUM ==> False
# of ==> ADP ==> False
# the ==> DET ==> False
# scientists ==> NOUN ==> False
# . ==> PUNCT ==> False
# RAW ==> ADJ ==> False
# joint ==> ADJ ==> False
# secretary ==> NOUN ==> False
# Colonel ==> PROPN ==> False
# Sunil ==> PROPN ==> False
# Luthra ==> PROPN ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> False
# Jim ==> PROPN ==> False
# was ==> AUX ==> False
# a ==> DET ==> False
# former ==> ADJ ==> False
# RAW ==> ADJ ==> False
# agent ==> NOUN ==> False
# and ==> CCONJ ==> False
# Kabir ==> PROPN ==> False
# 's ==> PART ==> False
# partner ==> NOUN ==> False
# : ==> PUNCT ==> False
# when ==> SCONJ ==> False
# he ==> PRON ==> False
# and ==> CCONJ ==> False
# his ==> PRON ==> False
# family ==> NOUN ==> False
# were ==> AUX ==> False
# kidnapped ==> VERB ==> False
# by ==> ADP ==> False
# Somalian ==> ADJ ==> False
# terrorists ==> NOUN ==> False
# , ==> PUNCT ==> False
# the ==> DET ==> False
# agency ==> NOUN ==> False
# refused ==> VERB ==> False
# to ==> PART ==> False
# negotiate ==> VERB ==> False
# with ==> ADP ==> False
# them ==> PRON ==> False
# ; ==> PUNCT ==> False
# as ==> ADP ==> False
# a ==> DET ==> False
# result ==> NOUN ==> False
# , ==> PUNCT ==> False
# the ==> DET ==> False
# terrorists ==> NOUN ==> False
# killed ==> VERB ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# wife ==> NOUN ==> False
# and ==> CCONJ ==> False
# unborn ==> ADJ ==> False
# child ==> NOUN ==> False
# . ==> PUNCT ==> False
# Jim ==> PROPN ==> False
# was ==> AUX ==> False
# posthumously ==> ADV ==> False
# awarded ==> VERB ==> False
# the ==> DET ==> False
# Vir ==> PROPN ==> False
# Chakra ==> PROPN ==> False
# for ==> ADP ==> False
# bravery ==> NOUN ==> False
# but ==> CCONJ ==> False
# he ==> PRON ==> False
# faked ==> VERB ==> False
# his ==> PRON ==> False
# death ==> NOUN ==> False
# and ==> CCONJ ==> False
# now ==> ADV ==> False
# seeks ==> VERB ==> False
# vengeance ==> NOUN ==> False
# against ==> ADP ==> False
# the ==> DET ==> False
# country ==> NOUN ==> False
# for ==> ADP ==> False
# abandoning ==> VERB ==> False
# him ==> PRON ==> False
# and ==> CCONJ ==> False
# his ==> PRON ==> False
# family ==> NOUN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# Pathaan ==> PROPN ==> False
# also ==> ADV ==> False
# learns ==> VERB ==> False
# of ==> ADP ==> False
# something ==> PRON ==> False
# called ==> VERB ==> False
# " ==> PUNCT ==> False
# Raktbeej ==> NOUN ==> False
# " ==> PUNCT ==> False
# and ==> CCONJ ==> False
# about ==> ADP ==> False
# Rubina ==> PROPN ==> False
# Mohsin ==> PROPN ==> False
# , ==> PUNCT ==> False
# a ==> DET ==> False
# Pakistani ==> ADJ ==> False
# doctor ==> NOUN ==> False
# in ==> ADP ==> False
# Spain ==> PROPN ==> False
# who ==> PRON ==> False
# works ==> VERB ==> False
# with ==> ADP ==> False
# Jim ==> PROPN ==> False
# . ==> PUNCT ==> False
# He ==> PRON ==> False
# travels ==> VERB ==> False
# to ==> ADP ==> False
# Spain ==> PROPN ==> False
# and ==> CCONJ ==> False
# is ==> AUX ==> False
# captured ==> VERB ==> False
# by ==> ADP ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# men ==> NOUN ==> False
# , ==> PUNCT ==> False
# where ==> SCONJ ==> False
# he ==> PRON ==> False
# learns ==> VERB ==> False
# that ==> SCONJ ==> False
# Rubina ==> PROPN ==> False
# is ==> AUX ==> False
# an ==> DET ==> False
# ex ==> ADJ ==> False
# - ==> ADJ ==> False
# ISI ==> ADJ ==> False
# agent ==> NOUN ==> False
# . ==> PUNCT ==> False
# Rubina ==> PROPN ==> False
# saves ==> VERB ==> False
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> False
# Raktbeej ==> NOUN ==> False
# is ==> AUX ==> False
# in ==> ADP ==> False
# Moscow ==> PROPN ==> False
# . ==> PUNCT ==> False
# They ==> PRON ==> False
# travel ==> VERB ==> False
# there ==> ADV ==> False
# to ==> PART ==> False
# steal ==> VERB ==> False
# it ==> PRON ==> False
# before ==> SCONJ ==> False
# Jim ==> PROPN ==> False
# does ==> VERB ==> False
# . ==> PUNCT ==> False
# Rubina ==> PROPN ==> False
# betrays ==> VERB ==> False
# Pathaan ==> PROPN ==> False
# , ==> PUNCT ==> False
# leaving ==> VERB ==> False
# him ==> PRON ==> False
# to ==> PART ==> False
# captured ==> VERB ==> False
# by ==> ADP ==> False
# the ==> DET ==> False
# Russian ==> ADJ ==> False
# police ==> NOUN ==> False
# . ==> PUNCT ==> False
# She ==> PRON ==> False
# had ==> AUX ==> False
# been ==> AUX ==> False
# working ==> VERB ==> False
# for ==> ADP ==> False
# Jim ==> PROPN ==> False
# all ==> ADV ==> False
# along ==> ADV ==> False
# . ==> PUNCT ==> False
# Pathaan ==> PROPN ==> False
# is ==> AUX ==> False
# taken ==> VERB ==> False
# to ==> ADP ==> False
# prison ==> NOUN ==> False
# by ==> ADP ==> False
# train ==> NOUN ==> False
# , ==> PUNCT ==> False
# where ==> SCONJ ==> False
# he ==> PRON ==> False
# is ==> AUX ==> False
# nearly ==> ADV ==> False
# murdered ==> VERB ==> False
# ; ==> PUNCT ==> False
# he ==> PRON ==> False
# is ==> AUX ==> False
# saved ==> VERB ==> False
# by ==> ADP ==> False
# fellow ==> ADJ ==> False
# agent ==> NOUN ==> False
# Tiger ==> PROPN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# Three ==> NUM ==> False
# years ==> NOUN ==> False
# later ==> ADV ==> False
# , ==> PUNCT ==> False
# during ==> ADP ==> False
# which ==> PRON ==> False
# Pathaan ==> PROPN ==> False
# was ==> AUX ==> False
# in ==> ADP ==> False
# hiding ==> NOUN ==> False
# , ==> PUNCT ==> False
# he ==> PRON ==> False
# captures ==> VERB ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# henchman ==> NOUN ==> False
# , ==> PUNCT ==> False
# Raafe ==> PROPN ==> False
# . ==> PUNCT ==> False
# Nandini ==> PROPN ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> False
# Rubina ==> PROPN ==> False
# was ==> AUX ==> False
# captured ==> VERB ==> False
# on ==> ADP ==> False
# CCTV ==> PROPN ==> False
# footage ==> NOUN ==> False
# in ==> ADP ==> False
# Paris ==> PROPN ==> False
# . ==> PUNCT ==> False
# Pathaan ==> PROPN ==> False
# realizes ==> VERB ==> False
# Rubina ==> PROPN ==> False
# wants ==> VERB ==> False
# him ==> PRON ==> False
# to ==> PART ==> False
# meet ==> VERB ==> False
# her ==> PRON ==> False
# there ==> ADV ==> False
# , ==> PUNCT ==> False
# and ==> CCONJ ==> False
# does ==> VERB ==> False
# so ==> ADV ==> False
# . ==> PUNCT ==> False
# Rubina ==> PROPN ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> False
# the ==> DET ==> False
# Raktbeej ==> NOUN ==> False
# is ==> AUX ==> False
# actually ==> ADV ==> False
# a ==> DET ==> False
# mutated ==> VERB ==> False
# version ==> NOUN ==> False
# of ==> ADP ==> False
# smallpox ==> NOUN ==> False
# ; ==> PUNCT ==> False
# a ==> DET ==> False
# deadly ==> ADJ ==> False
# virus ==> NOUN ==> False
# Jim ==> PROPN ==> False
# forced ==> VERB ==> False
# the ==> DET ==> False
# scientist ==> NOUN ==> False
# he ==> PRON ==> False
# 'd ==> AUX ==> False
# captured ==> VERB ==> False
# to ==> PART ==> False
# create ==> VERB ==> False
# . ==> PUNCT ==> False
# She ==> PRON ==> False
# expresses ==> VERB ==> False
# guilt ==> NOUN ==> False
# about ==> ADP ==> False
# betraying ==> VERB ==> False
# Pathaan ==> PROPN ==> False
# , ==> PUNCT ==> False
# not ==> PART ==> False
# knowing ==> VERB ==> False
# that ==> SCONJ ==> False
# her ==> PRON ==> False
# country ==> NOUN ==> False
# would ==> AUX ==> False
# plan ==> VERB ==> False
# such ==> DET ==> False
# an ==> DET ==> False
# attack ==> NOUN ==> False
# . ==> PUNCT ==> False
# They ==> PRON ==> False
# travel ==> VERB ==> False
# to ==> ADP ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# lab ==> NOUN ==> False
# in ==> ADP ==> False
# Siberia ==> PROPN ==> False
# and ==> CCONJ ==> False
# manage ==> VERB ==> False
# to ==> PART ==> False
# recover ==> VERB ==> False
# one ==> NUM ==> False
# orb ==> NOUN ==> False
# containing ==> VERB ==> False
# the ==> DET ==> False
# virus ==> NOUN ==> False
# while ==> SCONJ ==> False
# Jim ==> PROPN ==> False
# escapes ==> VERB ==> False
# with ==> ADP ==> False
# the ==> DET ==> False
# other ==> ADJ ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# They ==> PRON ==> False
# take ==> VERB ==> False
# the ==> DET ==> False
# orb ==> NOUN ==> False
# to ==> ADP ==> False
# the ==> DET ==> False
# lab ==> NOUN ==> False
# to ==> PART ==> False
# create ==> VERB ==> False
# a ==> DET ==> False
# vaccine ==> NOUN ==> False
# ; ==> PUNCT ==> False
# however ==> ADV ==> False
# , ==> PUNCT ==> False
# Jim ==> PROPN ==> False
# reveals ==> VERB ==> False
# that ==> SCONJ ==> False
# the ==> DET ==> False
# orb ==> NOUN ==> False
# has ==> AUX ==> False
# already ==> ADV ==> False
# spread ==> VERB ==> False
# the ==> DET ==> False
# virus ==> NOUN ==> False
# within ==> ADP ==> False
# the ==> DET ==> False
# lab ==> NOUN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> False
# infected ==> ADJ ==> False
# scientists ==> NOUN ==> False
# , ==> PUNCT ==> False
# along ==> ADP ==> False
# with ==> ADP ==> False
# Nandini ==> PROPN ==> False
# , ==> PUNCT ==> False
# die ==> NOUN ==> False
# , ==> PUNCT ==> False
# and ==> CCONJ ==> False
# the ==> DET ==> False
# lab ==> NOUN ==> False
# is ==> AUX ==> False
# destroyed ==> VERB ==> False
# to ==> PART ==> False
# prevent ==> VERB ==> False
# the ==> DET ==> False
# spread ==> NOUN ==> False
# of ==> ADP ==> False
# the ==> DET ==> False
# virus ==> NOUN ==> False
# . ==> PUNCT ==> False
# Pathaan ==> NOUN ==> False
# learns ==> VERB ==> False
# from ==> ADP ==> False
# Raafe ==> PROPN ==> False
# that ==> SCONJ ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# missile ==> NOUN ==> False
# is ==> AUX ==> False
# in ==> ADP ==> False
# Afghanistan ==> PROPN ==> False
# . ==> PUNCT ==> False
# By ==> ADP ==> False
# luring ==> VERB ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# soldiers ==> NOUN ==> False
# into ==> ADP ==> False
# a ==> DET ==> False
# trap ==> NOUN ==> False
# , ==> PUNCT ==> False
# his ==> PRON ==> False
# team ==> NOUN ==> False
# attacks ==> VERB ==> False
# Jim ==> PROPN ==> False
# 's ==> PART ==> False
# base ==> NOUN ==> False
# . ==> PUNCT ==> False
# Qadir ==> PROPN ==> False
# is ==> AUX ==> False
# killed ==> VERB ==> False
# by ==> ADP ==> False
# Rubina ==> PROPN ==> False
# and ==> CCONJ ==> False
# Pathaan ==> PROPN ==> False
# chases ==> NOUN ==> False
# after ==> ADP ==> False
# Jim ==> PROPN ==> False
# with ==> ADP ==> False
# a ==> DET ==> False
# jetpack ==> NOUN ==> False
# . ==> PUNCT ==> False
# They ==> PRON ==> False
# crash ==> NOUN ==> False
# - ==> PUNCT ==> False
# land ==> NOUN ==> False
# into ==> ADP ==> False
# a ==> DET ==> False
# cabin ==> NOUN ==> False
# atop ==> ADP ==> False
# a ==> DET ==> False
# cliff ==> NOUN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# Rubina ==> PROPN ==> False
# deactivates ==> VERB ==> False
# the ==> DET ==> False
# missile ==> NOUN ==> False
# containing ==> VERB ==> False
# the ==> DET ==> False
# virus ==> NOUN ==> False
# but ==> CCONJ ==> False
# finds ==> VERB ==> False
# that ==> SCONJ ==> False
# Raktbeej ==> NOUN ==> False
# is ==> AUX ==> False
# actually ==> ADV ==> False
# in ==> ADP ==> False
# a ==> DET ==> False
# passenger ==> NOUN ==> False
# - ==> PUNCT ==> False
# bound ==> VERB ==> False
# airplane ==> NOUN ==> False
# about ==> ADP ==> False
# to ==> PART ==> False
# land ==> VERB ==> False
# in ==> ADP ==> False
# Delhi ==> PROPN ==> False
# — ==> PUNCT ==> False
# and ==> CCONJ ==> False
# Jim ==> PROPN ==> False
# has ==> VERB ==> False
# the ==> DET ==> False
# detonator ==> NOUN ==> False
# . ==> PUNCT ==> False
# Luthra ==> PROPN ==> False
# remorsefully ==> ADV ==> False
# orders ==> VERB ==> False
# the ==> DET ==> False
# plane ==> NOUN ==> False
# to ==> PART ==> False
# be ==> AUX ==> False
# blown ==> VERB ==> False
# up ==> ADP ==> False
# to ==> PART ==> False
# prevent ==> VERB ==> False
# the ==> DET ==> False
# virus ==> NOUN ==> False
# ' ==> PART ==> False
# spread ==> NOUN ==> False
# as ==> ADP ==> False
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> False
# Jim ==> PROPN ==> False
# fight ==> NOUN ==> False
# . ==> PUNCT ==> False
# Pathaan ==> NOUN ==> False
# manages ==> VERB ==> False
# to ==> PART ==> False
# deactivate ==> VERB ==> False
# Raktbeej ==> NOUN ==> False
# and ==> CCONJ ==> False
# throw ==> VERB ==> False
# Jim ==> PROPN ==> False
# off ==> ADP ==> False
# the ==> DET ==> False
# cliff ==> NOUN ==> False
# , ==> PUNCT ==> False
# resulting ==> VERB ==> False
# in ==> ADP ==> False
# his ==> PRON ==> False
# apparent ==> ADJ ==> False
# death ==> NOUN ==> False
# . ==> PUNCT ==> False
# The ==> DET ==> False
# passenger ==> NOUN ==> False
# plane ==> NOUN ==> False
# lands ==> VERB ==> False
# safely ==> ADV ==> False
# and ==> CCONJ ==> False
# Pathaan ==> PROPN ==> False
# is ==> AUX ==> False
# reinstated ==> VERB ==> False
# into ==> ADP ==> False
# RAW ==> PROPN ==> False
# and ==> CCONJ ==> False
# made ==> VERB ==> False
# head ==> NOUN ==> False
# of ==> ADP ==> False
# JOCR ==> PROPN ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False
# In ==> ADP ==> False
# a ==> DET ==> False
# mid ==> ADJ ==> False
# - ==> NOUN ==> False
# credits ==> NOUN ==> False
# scene ==> NOUN ==> False
# , ==> PUNCT ==> False
# Pathaan ==> PROPN ==> False
# and ==> CCONJ ==> False
# Tiger ==> PROPN ==> False
# ponder ==> NOUN ==> False
# retiring ==> VERB ==> False
# and ==> CCONJ ==> False
# suggest ==> VERB ==> False
# younger ==> ADJ ==> False
# agents ==> NOUN ==> False
# who ==> PRON ==> False
# can ==> AUX ==> False
# replace ==> VERB ==> False
# them ==> PRON ==> False
# . ==> PUNCT ==> False
# Eventually ==> ADV ==> False
# , ==> PUNCT ==> False
# they ==> PRON ==> False
# decide ==> VERB ==> False
# those ==> DET ==> False
# agents ==> NOUN ==> False
# are ==> AUX ==> False
# n't ==> PART ==> False
# good ==> ADJ ==> False
# enough ==> ADV ==> False
# and ==> CCONJ ==> False
# they ==> PRON ==> False
# 'll ==> AUX ==> False
# have ==> VERB ==> False
# to ==> PART ==> False
# keep ==> VERB ==> False
# fighting ==> VERB ==> False
# the ==> DET ==> False
# threats ==> NOUN ==> False
# themselves ==> PRON ==> False
# . ==> PUNCT ==> False
#
#  ==> SPACE ==> False

# %% [markdown]
# ## Question 2

# %%
for ent in Doc.ents:
    print(ent.text,'==>',ent.label_)
# Out:
# 2023 ==> DATE
# Indian ==> NORP
# Hindi-language ==> PERSON
# Siddharth Anand ==> PERSON
# Aditya Chopra ==> PERSON
# Yash Raj Films ==> PERSON
# fourth ==> ORDINAL
# Shah Rukh Khan ==> PERSON
# Deepika Padukone ==> ORG
# John Abraham ==> PERSON
# Dimple Kapadia ==> PERSON
# Ashutosh Rana ==> GPE
# Shridhar Raghavan ==> PERSON
# Abbas Tyrewala ==> PERSON
# Anand ==> ORG
# RAW ==> ORG
# ISI ==> ORG
# Rubina ==> PERSON
# Jim ==> PERSON
# RAW ==> ORG
# India ==> GPE
# November 2020 ==> DATE
# Mumbai ==> GPE
# India ==> GPE
# Afghanistan ==> GPE
# Spain ==> GPE
# UAE ==> GPE
# Turkey ==> GPE
# Russia ==> GPE
# Italy ==> GPE
# France ==> GPE
# Two ==> CARDINAL
# Sanchit Balhara ==> PERSON
# one ==> CARDINAL
# Hindutva ==> NORP
# the Central Board of Film Certification ==> ORG
# 225 ==> MONEY
# US$28 million ==> MONEY
# 15 ==> MONEY
# US$1.9 million ==> MONEY
# India ==> GPE
# 25 January 2023 ==> DATE
# the Republic Day ==> GPE
# IMAX ==> GPE
# Tamil ==> GPE
# Telugu ==> ORG
# Indian ==> NORP
# Hindi ==> NORP
# 924 ==> MONEY
# US$120 million ==> MONEY
# Hindi film ==> PERSON
# 2023 ==> DATE
# fourth ==> ORDINAL
# Hindi film ==> PERSON
# seventh ==> ORDINAL
# Indian ==> NORP
# Khan ==> PERSON
# Yash Raj Films' ==> PERSON
# 2019 ==> DATE
# Indian ==> NORP
# Article 370 ==> LAW
# Jammu ==> GPE
# Kashmir ==> LOC
# Pakistani ==> NORP
# Qadir ==> GPE
# India ==> GPE
# Jim ==> PERSON
# RAW ==> ORG
# Nandini ==> PERSON
# Joint Operation ==> WORK_OF_ART
# Covert Research ==> PERSON
# JOCR ==> ORG
# Dubai ==> GPE
# two ==> CARDINAL
# Jim ==> PERSON
# one ==> CARDINAL
# Sunil Luthra ==> PERSON
# Jim ==> PERSON
# Kabir ==> GPE
# Somalian ==> NORP
# Jim ==> PERSON
# Jim ==> PERSON
# the Vir Chakra ==> ORG
# Raktbeej ==> WORK_OF_ART
# Rubina Mohsin ==> PERSON
# Pakistani ==> NORP
# Spain ==> GPE
# Jim ==> PERSON
# Spain ==> GPE
# Jim ==> PERSON
# Rubina ==> LOC
# Rubina ==> PERSON
# Moscow ==> GPE
# Jim ==> PERSON
# Rubina ==> PERSON
# Russian ==> NORP
# Jim ==> PERSON
# Three years later ==> DATE
# Jim ==> PERSON
# Rubina ==> LOC
# CCTV ==> ORG
# Paris ==> GPE
# Rubina ==> GPE
# Raktbeej ==> LOC
# Jim ==> PERSON
# Jim ==> PERSON
# Siberia ==> LOC
# Jim ==> PERSON
# Jim ==> PERSON
# Nandini ==> ORG
# Jim ==> PERSON
# Afghanistan ==> GPE
# Jim ==> PERSON
# Jim ==> PERSON
# Qadir ==> GPE
# Jim ==> PERSON
# Rubina ==> PERSON
# Raktbeej ==> PERSON
# Delhi ==> GPE
# Jim ==> PERSON
# Pathaan ==> PERSON
# Jim ==> PERSON
# Jim ==> PERSON
# JOCR ==> ORG

# %%
from spacy import displacy
displacy.render(Doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Pathaan is a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hindi-language
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  action thriller film directed by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Siddharth Anand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and produced by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aditya Chopra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yash Raj Films
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fourth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  instalment in the YRF Spy Universe, it stars
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shah Rukh Khan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deepika Padukone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Abraham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , alongside
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dimple Kapadia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ashutosh Rana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . Written by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shridhar Raghavan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Abbas Tyrewala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  from a story by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the film is about Pathaan, an exiled
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RAW
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  agent, who must work with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ISI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rubina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to take down
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jim
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a former
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RAW
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  agent-turned-traitor, who is planning to spread a deadly lab-generated virus across
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</br>Principal photography for Pathaan began in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . The film was shot over various locations in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius:

# %%
most_ent=[]
for ent in Doc.ents:
    most_ent.append(ent.text)
print(most_ent)
# Out:
# ['2023', 'Indian', 'Hindi-language', 'Siddharth Anand', 'Aditya Chopra', 'Yash Raj Films', 'fourth', 'Shah Rukh Khan', 'Deepika Padukone', 'John Abraham', 'Dimple Kapadia', 'Ashutosh Rana', 'Shridhar Raghavan', 'Abbas Tyrewala', 'Anand', 'RAW', 'ISI', 'Rubina', 'Jim', 'RAW', 'India', 'November 2020', 'Mumbai', 'India', 'Afghanistan', 'Spain', 'UAE', 'Turkey', 'Russia', 'Italy', 'France', 'Two', 'Sanchit Balhara', 'one', 'Hindutva', 'the Central Board of Film Certification', '225', 'US$28 million', '15', 'US$1.9 million', 'India', '25 January 2023', 'the Republic Day', 'IMAX', 'Tamil', 'Telugu', 'Indian', 'Hindi', '924', 'US$120 million', 'Hindi film', '2023', 'fourth', 'Hindi film', 'seventh', 'Indian', 'Khan', "Yash Raj Films'", '2019', 'Indian', 'Article 370', 'Jammu', 'Kashmir', 'Pakistani', 'Qadir', 'India', 'Jim', 'RAW', 'Nandini', 'Joint Operation', 'Covert Research', 'JOCR', 'Dubai', 'two', 'Jim', 'one', 'Sunil Luthra', 'Jim', 'Kabir', 'Somalian', 'Jim', 'Jim', 'the Vir Chakra', 'Raktbeej', 'Rubina Mohsin', 'Pakistani', 'Spain', 'Jim', 'Spain', 'Jim', 'Rubina', 'Rubina', 'Moscow', 'Jim', 'Rubina', 'Russian', 'Jim', 'Three years later', 'Jim', 'Rubina', 'CCTV', 'Paris', 'Rubina', 'Raktbeej', 'Jim', 'Jim', 'Siberia', 'Jim', 'Jim', 'Nandini', 'Jim', 'Afghanistan', 'Jim', 'Jim', 'Qadir', 'Jim', 'Rubina', 'Raktbeej', 'Delhi', 'Jim', 'Pathaan', 'Jim', 'Jim', 'JOCR']

# %%
from collections import Counter

# %%
Counter(most_ent).most_common()
# Out:
# [('Jim', 22),
#  ('Rubina', 7),
#  ('Indian', 4),
#  ('India', 4),
#  ('RAW', 3),
#  ('Spain', 3),
#  ('Raktbeej', 3),
#  ('2023', 2),
#  ('fourth', 2),
#  ('Afghanistan', 2),
#  ('one', 2),
#  ('Hindi film', 2),
#  ('Pakistani', 2),
#  ('Qadir', 2),
#  ('Nandini', 2),
#  ('JOCR', 2),
#  ('Hindi-language', 1),
#  ('Siddharth Anand', 1),
#  ('Aditya Chopra', 1),
#  ('Yash Raj Films', 1),
#  ('Shah Rukh Khan', 1),
#  ('Deepika Padukone', 1),
#  ('John Abraham', 1),
#  ('Dimple Kapadia', 1),
#  ('Ashutosh Rana', 1),
#  ('Shridhar Raghavan', 1),
#  ('Abbas Tyrewala', 1),
#  ('Anand', 1),
#  ('ISI', 1),
#  ('November 2020', 1),
#  ('Mumbai', 1),
#  ('UAE', 1),
#  ('Turkey', 1),
#  ('Russia', 1),
#  ('Italy', 1),
#  ('France', 1),
#  ('Two', 1),
#  ('Sanchit Balhara', 1),
#  ('Hindutva', 1),
#  ('the Central Board of Film Certification', 1),
#  ('225', 1),
#  ('US$28 million', 1),
#  ('15', 1),
#  ('US$1.9 million', 1),
#  ('25 January 2023', 1),
#  ('the Republic Day', 1),
#  ('IMAX', 1),
#  ('Tamil', 1),
#  ('Telugu', 1),
#  ('Hindi', 1),
#  ('924', 1),
#  ('US$120 million', 1),
#  ('seventh', 1),
#  ('Khan', 1),
#  ("Yash Raj Films'", 1),
#  ('2019', 1),
#  ('Article 370', 1),
#  ('Jammu', 1),
#  ('Kashmir', 1),
#  ('Joint Operation', 1),
#  ('Covert Research', 1),
#  ('Dubai', 1),
#  ('two', 1),
#  ('Sunil Luthra', 1),
#  ('Kabir', 1),
#  ('Somalian', 1),
#  ('the Vir Chakra', 1),
#  ('Rubina Mohsin', 1),
#  ('Moscow', 1),
#  ('Russian', 1),
#  ('Three years later', 1),
#  ('CCTV', 1),
#  ('Paris', 1),
#  ('Siberia', 1),
#  ('Delhi', 1),
#  ('Pathaan', 1)]

# %% [markdown]
# ## Create a DataFrame consisting of entities, types and explanation of types

# %%
entities = []
types = []
explanations = []

for ent in Doc.ents:
    entities.append(ent.text)
    types.append(ent.label_)
    explanations.append(spacy.explain(ent.label_))

df = pd.DataFrame({"Entity": entities, "Type": types, "Explanation": explanations})

print(df)
# Out:
#               Entity    Type                                     Explanation
# 0               2023    DATE           Absolute or relative dates or periods
# 1             Indian    NORP  Nationalities or religious or political groups
# 2     Hindi-language  PERSON                     People, including fictional
# 3    Siddharth Anand  PERSON                     People, including fictional
# 4      Aditya Chopra  PERSON                     People, including fictional
# ..               ...     ...                                             ...
# 119              Jim  PERSON                     People, including fictional
# 120          Pathaan  PERSON                     People, including fictional
# 121              Jim  PERSON                     People, including fictional
# 122              Jim  PERSON                     People, including fictional
# 123             JOCR     ORG         Companies, agencies, institutions, etc.
#
# [124 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
entity_types = [ent.label_ for ent in Doc.ents]
type_counts = {t: entity_types.count(t) for t in set(entity_types)}
plt.figure(figsize=(16, 6))
plt.bar(type_counts.keys(), type_counts.values())
plt.title("Entity Type Counts")
plt.xlabel("Entity Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Question3

# %%
from spacy.matcher import Matcher

# %%
text='''Pathaan is a 2023 Indian Hindi-language action thriller film directed by Siddharth Anand and produced by Aditya Chopra of Yash Raj Films. The fourth instalment in the YRF Spy Universe, it stars Shah Rukh Khan, Deepika Padukone, and John Abraham, alongside Dimple Kapadia and Ashutosh Rana. Written by Shridhar Raghavan and Abbas Tyrewala from a story by Anand, the film is about Pathaan, an exiled RAW agent, who must work with ISI agent Rubina to take down Jim, a former RAW agent-turned-traitor, who is planning to spread a deadly lab-generated virus across India.
Principal photography for Pathaan began in November 2020 in Mumbai. The film was shot over various locations in India, Afghanistan, Spain, UAE, Turkey, Russia, Italy and France. Two songs were composed by the duo Vishal–Shekhar, while Sanchit Balhara and Ankit Balhara provided the score. The music video of one song, "Besharam Rang", featured Padukone in a saffron bikini, which led to protests by right-wing Hindutva groups and an attempt to boycott the film; however, the Central Board of Film Certification cleared the film for exhibition after certain edits were made to the song sequence. The film was made on an estimated production budget of ₹225 crore (US$28 million) with a further ₹15 crore (US$1.9 million) spent on print and advertising. Against the norm, pre-release publicity was limited with no media interactions or public events.
Pathaan was released in India on 25 January 2023, coinciding with the Republic Day weekend, in IMAX, 4DX and standard formats along with dubbed versions in Tamil and Telugu. It received positive reviews from critics and broke several Indian box-office records, including the biggest opening day and opening weekend for a Hindi film. Further opening records were set in overseas markets. Grossing ₹924 crore (US$120 million) worldwide, Pathaan ranks as the highest-grossing Hindi film of 2023, the fourth-highest-grossing Hindi film and seventh-highest-grossing Indian film of all time, as well as the highest-grossing of Khan's career and Yash Raj Films' releases. 
In 2019, the Indian Government revokes Article 370, which grants special status for Jammu and Kashmir. The news impacts a cancer-ridden Pakistani army general, Qadir, who decides to exact vengeance against India. He signs a contract with Jim, who leads "Outfit X", a private terrorist organization. Meanwhile, Pathaan, a former RAW agent, and his senior officer Nandini, open a unit dubbed "Joint Operation and Covert Research" (JOCR), recruiting agents who were forced to retire due to trauma or injury.
Pathaan and his team head to Dubai to stop Outfit X from kidnapping two scientists. Jim fights Pathaan and manages to escape with one of the scientists. RAW joint secretary Colonel Sunil Luthra reveals that Jim was a former RAW agent and Kabir's partner: when he and his family were kidnapped by Somalian terrorists, the agency refused to negotiate with them; as a result, the terrorists killed Jim's wife and unborn child. Jim was posthumously awarded the Vir Chakra for bravery but he faked his death and now seeks vengeance against the country for abandoning him and his family.
Pathaan also learns of something called "Raktbeej" and about Rubina Mohsin, a Pakistani doctor in Spain who works with Jim. He travels to Spain and is captured by Jim's men, where he learns that Rubina is an ex-ISI agent. Rubina saves Pathaan and reveals that Raktbeej is in Moscow. They travel there to steal it before Jim does. Rubina betrays Pathaan, leaving him to captured by the Russian police. She had been working for Jim all along. Pathaan is taken to prison by train, where he is nearly murdered; he is saved by fellow agent Tiger.
Three years later, during which Pathaan was in hiding, he captures Jim's henchman, Raafe. Nandini reveals that Rubina was captured on CCTV footage in Paris. Pathaan realizes Rubina wants him to meet her there, and does so. Rubina reveals that the Raktbeej is actually a mutated version of smallpox; a deadly virus Jim forced the scientist he'd captured to create. She expresses guilt about betraying Pathaan, not knowing that her country would plan such an attack. They travel to Jim's lab in Siberia and manage to recover one orb containing the virus while Jim escapes with the other.
They take the orb to the lab to create a vaccine; however, Jim reveals that the orb has already spread the virus within the lab. The infected scientists, along with Nandini, die, and the lab is destroyed to prevent the spread of the virus. Pathaan learns from Raafe that Jim's missile is in Afghanistan. By luring Jim's soldiers into a trap, his team attacks Jim's base. Qadir is killed by Rubina and Pathaan chases after Jim with a jetpack. They crash-land into a cabin atop a cliff.
Rubina deactivates the missile containing the virus but finds that Raktbeej is actually in a passenger-bound airplane about to land in Delhi—and Jim has the detonator. Luthra remorsefully orders the plane to be blown up to prevent the virus' spread as Pathaan and Jim fight. Pathaan manages to deactivate Raktbeej and throw Jim off the cliff, resulting in his apparent death. The passenger plane lands safely and Pathaan is reinstated into RAW and made head of JOCR.
In a mid-credits scene, Pathaan and Tiger ponder retiring and suggest younger agents who can replace them. Eventually, they decide those agents aren't good enough and they'll have to keep fighting the threats themselves.

'''

# %%
doc=nlp(text)

# %%
matcher1=Matcher(nlp.vocab)

# %%
pattern1=[{'text':'‘Article 370’'}]

# %%
matcher1.add('WindowsPattern',[pattern1])

# %%
matches1=matcher1(doc)

print(len(matches1))
# Out:
# 0

# %% [markdown]
# ## But the file has once... but the code is not giving one

# %% [markdown]
# ## Question 4

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\yoges\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\yoges\anaconda3\lib\site-packages (from textblob) (3.6.1)
# Requirement already satisfied: regex in c:\users\yoges\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2021.4.4)
# Requirement already satisfied: joblib in c:\users\yoges\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.0.1)
# Requirement already satisfied: tqdm in c:\users\yoges\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.59.0)
# WARNING: You are using pip version 21.3.1; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\users\yoges\anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: click in c:\users\yoges\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (7.1.2)

# %%
nlp=spacy.load('en_core_web_sm')

# %%
text='''Pathaan is a 2023 Indian Hindi-language action thriller film directed by Siddharth Anand and produced by Aditya Chopra of Yash Raj Films. The fourth instalment in the YRF Spy Universe, it stars Shah Rukh Khan, Deepika Padukone, and John Abraham, alongside Dimple Kapadia and Ashutosh Rana. Written by Shridhar Raghavan and Abbas Tyrewala from a story by Anand, the film is about Pathaan, an exiled RAW agent, who must work with ISI agent Rubina to take down Jim, a former RAW agent-turned-traitor, who is planning to spread a deadly lab-generated virus across India.
Principal photography for Pathaan began in November 2020 in Mumbai. The film was shot over various locations in India, Afghanistan, Spain, UAE, Turkey, Russia, Italy and France. Two songs were composed by the duo Vishal–Shekhar, while Sanchit Balhara and Ankit Balhara provided the score. The music video of one song, "Besharam Rang", featured Padukone in a saffron bikini, which led to protests by right-wing Hindutva groups and an attempt to boycott the film; however, the Central Board of Film Certification cleared the film for exhibition after certain edits were made to the song sequence. The film was made on an estimated production budget of ₹225 crore (US$28 million) with a further ₹15 crore (US$1.9 million) spent on print and advertising. Against the norm, pre-release publicity was limited with no media interactions or public events.
Pathaan was released in India on 25 January 2023, coinciding with the Republic Day weekend, in IMAX, 4DX and standard formats along with dubbed versions in Tamil and Telugu. It received positive reviews from critics and broke several Indian box-office records, including the biggest opening day and opening weekend for a Hindi film. Further opening records were set in overseas markets. Grossing ₹924 crore (US$120 million) worldwide, Pathaan ranks as the highest-grossing Hindi film of 2023, the fourth-highest-grossing Hindi film and seventh-highest-grossing Indian film of all time, as well as the highest-grossing of Khan's career and Yash Raj Films' releases. 
In 2019, the Indian Government revokes Article 370, which grants special status for Jammu and Kashmir. The news impacts a cancer-ridden Pakistani army general, Qadir, who decides to exact vengeance against India. He signs a contract with Jim, who leads "Outfit X", a private terrorist organization. Meanwhile, Pathaan, a former RAW agent, and his senior officer Nandini, open a unit dubbed "Joint Operation and Covert Research" (JOCR), recruiting agents who were forced to retire due to trauma or injury.
Pathaan and his team head to Dubai to stop Outfit X from kidnapping two scientists. Jim fights Pathaan and manages to escape with one of the scientists. RAW joint secretary Colonel Sunil Luthra reveals that Jim was a former RAW agent and Kabir's partner: when he and his family were kidnapped by Somalian terrorists, the agency refused to negotiate with them; as a result, the terrorists killed Jim's wife and unborn child. Jim was posthumously awarded the Vir Chakra for bravery but he faked his death and now seeks vengeance against the country for abandoning him and his family.
Pathaan also learns of something called "Raktbeej" and about Rubina Mohsin, a Pakistani doctor in Spain who works with Jim. He travels to Spain and is captured by Jim's men, where he learns that Rubina is an ex-ISI agent. Rubina saves Pathaan and reveals that Raktbeej is in Moscow. They travel there to steal it before Jim does. Rubina betrays Pathaan, leaving him to captured by the Russian police. She had been working for Jim all along. Pathaan is taken to prison by train, where he is nearly murdered; he is saved by fellow agent Tiger.
Three years later, during which Pathaan was in hiding, he captures Jim's henchman, Raafe. Nandini reveals that Rubina was captured on CCTV footage in Paris. Pathaan realizes Rubina wants him to meet her there, and does so. Rubina reveals that the Raktbeej is actually a mutated version of smallpox; a deadly virus Jim forced the scientist he'd captured to create. She expresses guilt about betraying Pathaan, not knowing that her country would plan such an attack. They travel to Jim's lab in Siberia and manage to recover one orb containing the virus while Jim escapes with the other.
They take the orb to the lab to create a vaccine; however, Jim reveals that the orb has already spread the virus within the lab. The infected scientists, along with Nandini, die, and the lab is destroyed to prevent the spread of the virus. Pathaan learns from Raafe that Jim's missile is in Afghanistan. By luring Jim's soldiers into a trap, his team attacks Jim's base. Qadir is killed by Rubina and Pathaan chases after Jim with a jetpack. They crash-land into a cabin atop a cliff.
Rubina deactivates the missile containing the virus but finds that Raktbeej is actually in a passenger-bound airplane about to land in Delhi—and Jim has the detonator. Luthra remorsefully orders the plane to be blown up to prevent the virus' spread as Pathaan and Jim fight. Pathaan manages to deactivate Raktbeej and throw Jim off the cliff, resulting in his apparent death. The passenger plane lands safely and Pathaan is reinstated into RAW and made head of JOCR.
In a mid-credits scene, Pathaan and Tiger ponder retiring and suggest younger agents who can replace them. Eventually, they decide those agents aren't good enough and they'll have to keep fighting the threats themselves.

'''

# %%
doc=nlp(text)

# %%
from textblob import TextBlob

# %%
text_1=TextBlob(text)

# %%
text_1.sentiment
# Out:
# Sentiment(polarity=-0.028834657406085984, subjectivity=0.2985909215501052)
